# %%
# %pip install cloudscraper

import pandas as pd
from bs4 import BeautifulSoup, Comment
import re
import cloudscraper
import time
import random
import csv
import numpy as np

SEASON_LIST=['2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']
SEASON_URL = 'https://www.pro-football-reference.com/years/{}/games.htm'
GAME_URL = 'https://www.pro-football-reference.com/boxscores/{}.htm' # add game_id to the end of it
GAME_URL_LIST = []

# %%
# Create a scraper that bypasses Cloudflare
scraper = cloudscraper.create_scraper(
    browser={
        'browser': 'chrome',
        'platform': 'windows',
        'mobile': False
    }
)

game_id_list = []

for year in SEASON_LIST:
    url = SEASON_URL.format(year)
    # print(f"Processing {year}...")
    
    # Add random delay
    time.sleep(random.uniform(2, 4))
    
    try:
        response = scraper.get(url)
        # print(f"Status code: {response.status_code}")
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            # print(f"Successfully fetched {url}")
            
            # Find the table with id="games"
            games_table = soup.find('table', {'id': 'games'})
            
            if games_table:
                # print(f"Found games table for {year}")

                # Method 1: Exact text match
                boxscore_links = games_table.find_all('a', string='boxscore')
                
                print(f"Found {len(boxscore_links)} boxscore links for {year}")
                
                # Extract href attributes
                for link in boxscore_links:
                    href = link.get('href')
                    if href:
                        # print(f"Found href: {href}")

                        # 1. Get the last part after last slash
                        game_id = href.split('/')[-1]
                        
                        # 2. Remove file extension if present
                        if '.' in game_id:
                            game_id = game_id.split('.')[0]
                            
                        
                        game_id_list.append(game_id)
                        # print(f"  → Extracted game ID: {game_id}")
        else:
            print(f"Failed with status: {response.status_code}")
            
    except Exception as e:
        print(f"Error: {e}")

# print(len(game_id_list))
game_id_list
# Out:
# Found 267 boxscore links for 2016
# Found 267 boxscore links for 2017
# Found 267 boxscore links for 2018
# Found 267 boxscore links for 2019
# Found 269 boxscore links for 2020
# Found 285 boxscore links for 2021
# Found 284 boxscore links for 2022
# Found 285 boxscore links for 2023
# Found 285 boxscore links for 2024
# Found 256 boxscore links for 2025
# ['201609080den',
#  '201609110rav',
#  '201609110jax',
#  '201609110atl',
#  '201609110htx',
#  '201609110nyj',
#  '201609110phi',
#  '201609110kan',
#  '201609110oti',
#  '201609110nor',
#  '201609110sea',
#  '201609110clt',
#  '201609110dal',
#  '201609110crd',
#  '201609120was',
#  '201609120sfo',
#  '201609150buf',
#  '201609180pit',
#  '201609180cle',
#  '201609180det',
#  '201609180htx',
#  '201609180nwe',
#  '201609180car',
#  '201609180was',
#  '201609180nyg',
#  '201609180crd',
#  '201609180ram',
#  '201609180rai',
#  '201609180den',
#  '201609180sdg',
#  '201609180min',
#  '201609190chi',
#  '201609220nwe',
#  '201609250buf',
#  '201609250car',
#  '201609250cin',
#  '201609250mia',
#  '201609250gnb',
#  '201609250jax',
#  '201609250nyg',
#  '201609250oti',
#  '201609250tam',
#  '201609250sea',
#  '201609250clt',
#  '201609250phi',
#  '201609250kan',
#  '201609250dal',
#  '201609260nor',
#  '201609290cin',
#  '201610020jax',
#  '201610020chi',
#  '201610020nwe',
#  '201610020htx',
#  '201610020rav',
#  '201610020nyj',
#  '201610020atl',
#  '201610020was',
#  '201610020tam',
#  '201610020crd',
#  '201610020sfo',
#  '201610020sdg',
#  '201610020pit',
#  '201610030min',
#  '201610060sfo',
#  '201610090clt',
#  '201610090cle',
#  '201610090det',
#  '201610090mia',
#  '201610090pit',
#  '201610090rav',
#  '201610090min',
#  '201610090den',
#  '201610090ram',
#  '201610090dal',
#  '201610090rai',
#  '201610090gnb',
#  '201610100car',
#  '201610130sdg',
#  '201610160buf',
#  '201610160chi',
#  '201610160nwe',
#  '201610160oti',
#  '201610160det',
#  '201610160mia',
#  '201610160nyg',
#  '201610160was',
#  '201610160nor',
#  '201610160rai',
#  '201610160gnb',
#  '201610160sea',
#  '201610160htx',
#  '201610170crd',
#  '201610200gnb',
#  '201610230ram',
#  '201610230jax',
#  '201610230phi',
#  '201610230mia',
#  '201610230cin',
#  '201610230oti',
#  '201610230det',
#  '201610230kan',
#  '201610230nyj',
#  '201610230atl',
#  '201610230sfo',
#  '201610230pit',
#  '201610230crd',
#  '201610240den',
#  '201610270oti',
#  '201610300cin',
#  '201610300car',
#  '201610300buf',
#  '201610300cle',
#  '201610300clt',
#  '201610300tam',
#  '201610300nor',
#  '201610300htx',
#  '201610300den',
#  '201610300atl',
#  '201610300dal',
#  '201610310chi',
#  '201611030tam',
#  '201611060kan',
#  '201611060mia',
#  '201611060nyg',
#  '201611060rav',
#  '201611060cle',
#  '201611060min',
#  '201611060ram',
#  '201611060sfo',
#  '201611060gnb',
#  '201611060sdg',
#  '201611060rai',
#  '201611070sea',
#  '201611100rav',
#  '201611130car',
#  '201611130tam',
#  '201611130oti',
#  '201611130jax',
#  '201611130was',
#  '201611130phi',
#  '201611130nor',
#  '201611130nyj',
#  '201611130sdg',
#  '201611130crd',
#  '201611130pit',
#  '201611130nwe',
#  '201611140nyg',
#  '201611170car',
#  '201611200cin',
#  '201611200nyg',
#  '201611200clt',
#  '201611200min',
#  '201611200dal',
#  '201611200det',
#  '201611200kan',
#  '201611200cle',
#  '201611200ram',
#  '201611200sfo',
#  '201611200sea',
#  '201611200was',
#  '201611210rai',
#  '201611240det',
#  '201611240dal',
#  '201611240clt',
#  '201611270atl',
#  '201611270buf',
#  '201611270chi',
#  '201611270rav',
#  '201611270htx',
#  '201611270mia',
#  '201611270nor',
#  '201611270cle',
#  '201611270tam',
#  '201611270rai',
#  '201611270nyj',
#  '201611270den',
#  '201611280phi',
#  '201612010min',
#  '201612040atl',
#  '201612040chi',
#  '201612040cin',
#  '201612040jax',
#  '201612040nor',
#  '201612040gnb',
#  '201612040rav',
#  '201612040nwe',
#  '201612040rai',
#  '201612040crd',
#  '201612040pit',
#  '201612040sdg',
#  '201612040sea',
#  '201612050nyj',
#  '201612080kan',
#  '201612110buf',
#  '201612110car',
#  '201612110det',
#  '201612110cle',
#  '201612110clt',
#  '201612110mia',
#  '201612110oti',
#  '201612110jax',
#  '201612110phi',
#  '201612110sfo',
#  '201612110ram',
#  '201612110gnb',
#  '201612110tam',
#  '201612110nyg',
#  '201612120nwe',
#  '201612150sea',
#  '201612170nyj',
#  '201612180buf',
#  '201612180chi',
#  '201612180cin',
#  '201612180min',
#  '201612180nyg',
#  '201612180htx',
#  '201612180kan',
#  '201612180rav',
#  '201612180atl',
#  '201612180crd',
#  '201612180den',
#  '201612180sdg',
#  '201612180dal',
#  '201612190was',
#  '201612220phi',
#  '201612240car',
#  '201612240buf',
#  '201612240chi',
#  '201612240cle',
#  '201612240gnb',
#  '201612240jax',
#  '201612240nwe',
#  '201612240rai',
#  '201612240sea',
#  '201612240nor',
#  '201612240ram',
#  '201612240htx',
#  '201612250pit',
#  '201612250kan',
#  '201612260dal',
#  '201701010nyj',
#  '201701010tam',
#  '201701010min',
#  '201701010cin',
#  '201701010pit',
#  '201701010clt',
#  '201701010phi',
#  '201701010oti',
#  '201701010mia',
#  '201701010atl',
#  '201701010ram',
#  '201701010den',
#  '201701010sdg',
#  '201701010was',
#  '201701010sfo',
#  '201701010det',
#  '201701070htx',
#  '201701070sea',
#  '201701080pit',
#  '201701080gnb',
#  '201701140atl',
#  '201701140nwe',
#  '201701150dal',
#  '201701150kan',
#  '201701220atl',
#  '201701220nwe',
#  '201702050atl',
#  '201709070nwe',
#  '201709100chi',
#  '201709100buf',
#  '201709100cin',
#  '201709100cle',
#  '201709100det',
#  '201709100htx',
#  '201709100oti',
#  '201709100was',
#  '201709100ram',
#  '201709100sfo',
#  '201709100gnb',
#  '201709100dal',
#  '201709110min',
#  '201709110den',
#  '201709140cin',
#  '201709170car',
#  '201709170tam',
#  '201709170rav',
#  '201709170clt',
#  '201709170jax',
#  '201709170kan',
#  '201709170pit',
#  '201709170nor',
#  '201709170sdg',
#  '201709170rai',
#  '201709170den',
#  '201709170ram',
#  '201709170sea',
#  '201709170atl',
#  '201709180nyg',
#  '201709210sfo',
#  '201709240jax',
#  '201709240nyj',
#  '201709240det',
#  '201709240buf',
#  '201709240car',
#  '201709240chi',
#  '201709240clt',
#  '201709240nwe',
#  '201709240min',
#  '201709240phi',
#  '201709240oti',
#  '201709240gnb',
#  '201709240sdg',
#  '201709240was',
#  '201709250crd',
#  '201709280gnb',
#  '201710010mia',
#  '201710010atl',
#  '201710010nwe',
#  '201710010cle',
#  '201710010dal',
#  '201710010min',
#  '201710010htx',
#  '201710010nyj',
#  '201710010rav',
#  '201710010crd',
#  '201710010tam',
#  '201710010sdg',
#  '201710010den',
#  '201710010sea',
#  '201710020kan',
#  '201710050tam',
#  '201710080mia',
#  '201710080cin',
#  '201710080det',
#  '201710080cle',
#  '201710080clt',
#  '201710080phi',
#  '201710080pit',
#  '201710080nyg',
#  '201710080rai',
#  '201710080ram',
#  '201710080dal',
#  '201710080htx',
#  '201710090chi',
#  '201710120car',
#  '201710150atl',
#  '201710150rav',
#  '201710150htx',
#  '201710150nor',
#  '201710150min',
#  '201710150nyj',
#  '201710150was',
#  '201710150crd',
#  '201710150jax',
#  '201710150kan',
#  '201710150rai',
#  '201710150den',
#  '201710160oti',
#  '201710190rai',
#  '201710220buf',
#  '201710220mia',
#  '201710220chi',
#  '201710220cle',
#  '201710220clt',
#  '201710220ram',
#  '201710220gnb',
#  '201710220min',
#  '201710220sfo',
#  '201710220pit',
#  '201710220sdg',
#  '201710220nyg',
#  '201710220nwe',
#  '201710230phi',
#  '201710260rav',
#  '201710290cle',
#  '201710290nyj',
#  '201710290buf',
#  '201710290cin',
#  '201710290tam',
#  '201710290nor',
#  '201710290nwe',
#  '201710290phi',
#  '201710290sea',
#  '201710290was',
#  '201710290det',
#  '201710300kan',
#  '201711020nyj',
#  '201711050car',
#  '201711050jax',
#  '201711050phi',
#  '201711050nor',
#  '201711050nyg',
#  '201711050oti',
#  '201711050htx',
#  '201711050sfo',
#  '201711050sea',
#  '201711050dal',
#  '201711050mia',
#  '201711060gnb',
#  '201711090crd',
#  '201711120buf',
#  '201711120chi',
#  '201711120oti',
#  '201711120det',
#  '201711120jax',
#  '201711120was',
#  '201711120clt',
#  '201711120tam',
#  '201711120ram',
#  '201711120atl',
#  '201711120sfo',
#  '201711120den',
#  '201711130car',
#  '201711160pit',
#  '201711190chi',
#  '201711190cle',
#  '201711190htx',
#  '201711190gnb',
#  '201711190nyg',
#  '201711190mia',
#  '201711190min',
#  '201711190nor',
#  '201711190sdg',
#  '201711190den',
#  '201711190rai',
#  '201711190dal',
#  '201711200sea',
#  '201711230det',
#  '201711230dal',
#  '201711230was',
#  '201711260atl',
#  '201711260kan',
#  '201711260nyj',
#  '201711260phi',
#  '201711260cin',
#  '201711260clt',
#  '201711260nwe',
#  '201711260sfo',
#  '201711260crd',
#  '201711260rai',
#  '201711260ram',
#  '201711260pit',
#  '201711270rav',
#  '201711300dal',
#  '201712030atl',
#  '201712030buf',
#  '201712030chi',
#  '201712030jax',
#  '201712030mia',
#  '201712030rav',
#  '201712030gnb',
#  '201712030oti',
#  '201712030nyj',
#  '201712030sdg',
#  '201712030nor',
#  '201712030crd',
#  '201712030rai',
#  '201712030sea',
#  '201712040cin',
#  '201712070atl',
#  '201712100buf',
#  '201712100car',
#  '201712100cin',
#  '201712100cle',
#  '201712100nyg',
#  '201712100tam',
#  '201712100htx',
#  '201712100kan',
#  '201712100crd',
#  '201712100den',
#  '201712100sdg',
#  '201712100jax',
#  '201712100ram',
#  '201712100pit',
#  '201712110mia',
#  '201712140clt',
#  '201712160det',
#  '201712160kan',
#  '201712170buf',
#  '201712170car',
#  '201712170min',
#  '201712170cle',
#  '201712170was',
#  '201712170jax',
#  '201712170nor',
#  '201712170nyg',
#  '201712170sea',
#  '201712170pit',
#  '201712170sfo',
#  '201712170rai',
#  '201712180tam',
#  '201712230rav',
#  '201712230gnb',
#  '201712240nor',
#  '201712240nwe',
#  '201712240car',
#  '201712240chi',
#  '201712240cin',
#  '201712240was',
#  '201712240kan',
#  '201712240nyj',
#  '201712240oti',
#  '201712240sfo',
#  '201712240crd',
#  '201712240dal',
#  '201712250htx',
#  '201712250phi',
#  '201712310min',
#  '201712310pit',
#  '201712310clt',
#  '201712310phi',
#  '201712310det',
#  '201712310nwe',
#  '201712310nyg',
#  '201712310atl',
#  '201712310mia',
#  '201712310rav',
#  '201712310sea',
#  '201712310den',
#  '201712310oti',
#  '201712310tam',
#  '201712310sdg',
#  '201712310ram',
#  '201801060kan',
#  '201801060ram',
#  '201801070jax',
#  '201801070nor',
#  '201801130phi',
#  '201801130nwe',
#  '201801140pit',
#  '201801140min',
#  '201801210nwe',
#  '201801210phi',
#  '201802040nwe',
#  '201809060phi',
#  '201809090rav',
#  '201809090clt',
#  '201809090cle',
#  '201809090nwe',
#  '201809090nyg',
#  '201809090mia',
#  '201809090min',
#  '201809090nor',
#  '201809090sdg',
#  '201809090car',
#  '201809090crd',
#  '201809090den',
#  '201809090gnb',
#  '201809100det',
#  '201809100rai',
#  '201809130cin',
#  '201809160atl',
#  '201809160buf',
#  '201809160nor',
#  '201809160was',
#  '201809160gnb',
#  '201809160oti',
#  '201809160pit',
#  '201809160nyj',
#  '201809160tam',
#  '201809160ram',
#  '201809160sfo',
#  '201809160den',
#  '201809160jax',
#  '201809160dal',
#  '201809170chi',
#  '201809200cle',
#  '201809230atl',
#  '201809230min',
#  '201809230car',
#  '201809230phi',
#  '201809230rav',
#  '201809230was',
#  '201809230htx',
#  '201809230jax',
#  '201809230kan',
#  '201809230mia',
#  '201809230ram',
#  '201809230crd',
#  '201809230sea',
#  '201809230det',
#  '201809240tam',
#  '201809270ram',
#  '201809300atl',
#  '201809300gnb',
#  '201809300chi',
#  '201809300clt',
#  '201809300dal',
#  '201809300jax',
#  '201809300nwe',
#  '201809300oti',
#  '201809300rai',
#  '201809300crd',
#  '201809300nyg',
#  '201809300sdg',
#  '201809300pit',
#  '201810010den',
#  '201810040nwe',
#  '201810070car',
#  '201810070pit',
#  '201810070buf',
#  '201810070cin',
#  '201810070cle',
#  '201810070nyj',
#  '201810070det',
#  '201810070kan',
#  '201810070sdg',
#  '201810070sfo',
#  '201810070phi',
#  '201810070sea',
#  '201810070htx',
#  '201810080nor',
#  '201810110nyg',
#  '201810140was',
#  '201810140mia',
#  '201810140atl',
#  '201810140htx',
#  '201810140cin',
#  '201810140cle',
#  '201810140nyj',
#  '201810140min',
#  '201810140rai',
#  '201810140den',
#  '201810140dal',
#  '201810140oti',
#  '201810140nwe',
#  '201810150gnb',
#  '201810180crd',
#  '201810210sdg',
#  '201810210phi',
#  '201810210chi',
#  '201810210mia',
#  '201810210clt',
#  '201810210tam',
#  '201810210jax',
#  '201810210nyj',
#  '201810210rav',
#  '201810210was',
#  '201810210sfo',
#  '201810210kan',
#  '201810220atl',
#  '201810250htx',
#  '201810280jax',
#  '201810280car',
#  '201810280chi',
#  '201810280det',
#  '201810280cin',
#  '201810280pit',
#  '201810280kan',
#  '201810280nyg',
#  '201810280rai',
#  '201810280ram',
#  '201810280crd',
#  '201810280min',
#  '201810290buf',
#  '201811010sfo',
#  '201811040was',
#  '201811040car',
#  '201811040min',
#  '201811040rav',
#  '201811040buf',
#  '201811040cle',
#  '201811040mia',
#  '201811040sea',
#  '201811040den',
#  '201811040nor',
#  '201811040nwe',
#  '201811050dal',
#  '201811080pit',
#  '201811110cle',
#  '201811110chi',
#  '201811110cin',
#  '201811110clt',
#  '201811110kan',
#  '201811110tam',
#  '201811110nyj',
#  '201811110oti',
#  '201811110rai',
#  '201811110gnb',
#  '201811110ram',
#  '201811110phi',
#  '201811120sfo',
#  '201811150sea',
#  '201811180atl',
#  '201811180det',
#  '201811180rav',
#  '201811180clt',
#  '201811180was',
#  '201811180jax',
#  '201811180nyg',
#  '201811180crd',
#  '201811180sdg',
#  '201811180nor',
#  '201811180chi',
#  '201811190ram',
#  '201811220det',
#  '201811220dal',
#  '201811220nor',
#  '201811250buf',
#  '201811250car',
#  '201811250cin',
#  '201811250nyj',
#  '201811250phi',
#  '201811250rav',
#  '201811250tam',
#  '201811250sdg',
#  '201811250clt',
#  '201811250den',
#  '201811250min',
#  '201811260htx',
#  '201811290dal',
#  '201812020atl',
#  '201812020mia',
#  '201812020tam',
#  '201812020nyg',
#  '201812020cin',
#  '201812020htx',
#  '201812020jax',
#  '201812020gnb',
#  '201812020det',
#  '201812020rai',
#  '201812020oti',
#  '201812020nwe',
#  '201812020sea',
#  '201812020pit',
#  '201812030phi',
#  '201812060oti',
#  '201812090gnb',
#  '201812090buf',
#  '201812090cle',
#  '201812090htx',
#  '201812090kan',
#  '201812090mia',
#  '201812090tam',
#  '201812090was',
#  '201812090sdg',
#  '201812090sfo',
#  '201812090crd',
#  '201812090dal',
#  '201812090rai',
#  '201812090chi',
#  '201812100sea',
#  '201812130kan',
#  '201812150nyj',
#  '201812150den',
#  '201812160atl',
#  '201812160buf',
#  '201812160chi',
#  '201812160cin',
#  '201812160clt',
#  '201812160jax',
#  '201812160min',
#  '201812160nyg',
#  '201812160rav',
#  '201812160sfo',
#  '201812160pit',
#  '201812160ram',
#  '201812170car',
#  '201812220oti',
#  '201812220sdg',
#  '201812230car',
#  '201812230nwe',
#  '201812230cle',
#  '201812230clt',
#  '201812230dal',
#  '201812230det',
#  '201812230nyj',
#  '201812230phi',
#  '201812230mia',
#  '201812230sfo',
#  '201812230crd',
#  '201812230nor',
#  '201812230sea',
#  '201812240rai',
#  '201812300tam',
#  '201812300buf',
#  '201812300nor',
#  '201812300nyg',
#  '201812300gnb',
#  '201812300htx',
#  '201812300nwe',
#  '201812300min',
#  '201812300pit',
#  '201812300rav',
#  '201812300sea',
#  '201812300den',
#  '201812300kan',
#  '201812300was',
#  '201812300ram',
#  '201812300oti',
#  '201901050htx',
#  '201901050dal',
#  '201901060rav',
#  '201901060chi',
#  '201901120kan',
#  '201901120ram',
#  '201901130nwe',
#  '201901130nor',
#  '201901200nor',
#  '201901200kan',
#  '201902030ram',
#  '201909050chi',
#  '201909080min',
#  '201909080nyj',
#  '201909080car',
#  '201909080cle',
#  '201909080jax',
#  '201909080mia',
#  '201909080phi',
#  '201909080sea',
#  '201909080sdg',
#  '201909080crd',
#  '201909080dal',
#  '201909080tam',
#  '201909080nwe',
#  '201909090nor',
#  '201909090rai',
#  '201909120car',
#  '201909150nyg',
#  '201909150cin',
#  '201909150oti',
#  '201909150rav',
#  '201909150was',
#  '201909150det',
#  '201909150gnb',
#  '201909150htx',
#  '201909150mia',
#  '201909150pit',
#  '201909150rai',
#  '201909150den',
#  '201909150ram',
#  '201909150atl',
#  '201909160nyj',
#  '201909190jax',
#  '201909220clt',
#  '201909220buf',
#  '201909220dal',
#  '201909220gnb',
#  '201909220phi',
#  '201909220kan',
#  '201909220min',
#  '201909220nwe',
#  '201909220crd',
#  '201909220tam',
#  '201909220sdg',
#  '201909220sea',
#  '201909220sfo',
#  '201909220cle',
#  '201909230was',
#  '201909260gnb',
#  '201909290atl',
#  '201909290buf',
#  '201909290htx',
#  '201909290rav',
#  '201909290clt',
#  '201909290det',
#  '201909290mia',
#  '201909290nyg',
#  '201909290crd',
#  '201909290ram',
#  '201909290chi',
#  '201909290den',
#  '201909290nor',
#  '201909300pit',
#  '201910030sea',
#  '201910060phi',
#  '201910060htx',
#  '201910060oti',
#  '201910060car',
#  '201910060rai',
#  '201910060cin',
#  '201910060nyg',
#  '201910060nor',
#  '201910060was',
#  '201910060pit',
#  '201910060sdg',
#  '201910060dal',
#  '201910060kan',
#  '201910070sfo',
#  '201910100nwe',
#  '201910130tam',
#  '201910130mia',
#  '201910130rav',
#  '201910130cle',
#  '201910130kan',
#  '201910130jax',
#  '201910130min',
#  '201910130crd',
#  '201910130ram',
#  '201910130nyj',
#  '201910130den',
#  '201910130sdg',
#  '201910140gnb',
#  '201910170den',
#  '201910200buf',
#  '201910200clt',
#  '201910200det',
#  '201910200was',
#  '201910200atl',
#  '201910200cin',
#  '201910200nyg',
#  '201910200gnb',
#  '201910200oti',
#  '201910200chi',
#  '201910200sea',
#  '201910200dal',
#  '201910210nyj',
#  '201910240min',
#  '201910270buf',
#  '201910270chi',
#  '201910270clt',
#  '201910270det',
#  '201910270atl',
#  '201910270ram',
#  '201910270nor',
#  '201910270jax',
#  '201910270oti',
#  '201910270sfo',
#  '201910270nwe',
#  '201910270htx',
#  '201910270kan',
#  '201910280pit',
#  '201910310crd',
#  '201911030jax',
#  '201911030buf',
#  '201911030car',
#  '201911030phi',
#  '201911030pit',
#  '201911030mia',
#  '201911030kan',
#  '201911030rai',
#  '201911030sea',
#  '201911030den',
#  '201911030sdg',
#  '201911030rav',
#  '201911040nyg',
#  '201911070rai',
#  '201911100nor',
#  '201911100cle',
#  '201911100chi',
#  '201911100cin',
#  '201911100tam',
#  '201911100oti',
#  '201911100nyj',
#  '201911100clt',
#  '201911100gnb',
#  '201911100pit',
#  '201911100dal',
#  '201911110sfo',
#  '201911140cle',
#  '201911170car',
#  '201911170mia',
#  '201911170clt',
#  '201911170det',
#  '201911170min',
#  '201911170rav',
#  '201911170tam',
#  '201911170was',
#  '201911170sfo',
#  '201911170rai',
#  '201911170phi',
#  '201911170ram',
#  '201911180sdg',
#  '201911210htx',
#  '201911240atl',
#  '201911240buf',
#  '201911240nor',
#  '201911240chi',
#  '201911240cin',
#  '201911240cle',
#  '201911240was',
#  '201911240nyj',
#  '201911240phi',
#  '201911240oti',
#  '201911240nwe',
#  '201911240sfo',
#  '201911250ram',
#  '201911280det',
#  '201911280dal',
#  '201911280atl',
#  '201912010car',
#  '201912010cin',
#  '201912010pit',
#  '201912010clt',
#  '201912010nyg',
#  '201912010jax',
#  '201912010mia',
#  '201912010rav',
#  '201912010crd',
#  '201912010den',
#  '201912010kan',
#  '201912010htx',
#  '201912020sea',
#  '201912050chi',
#  '201912080atl',
#  '201912080buf',
#  '201912080cle',
#  '201912080tam',
#  '201912080htx',
#  '201912080min',
#  ...]

# %%
# get the qb stuff
def get_data(game_id_list):
   for game_id in game_id_list:

      failed_ids = []

      url = GAME_URL.format(game_id)
      print("Processing: " + url)

      # Add random delay
      time.sleep(random.uniform(2, 4))

      try:
         response = scraper.get(url)
         print(f"Status code: {response.status_code}")
         
         if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            print(f"Successfully fetched {url}")            
                  
            comments = soup.find_all(string=lambda text: isinstance(text, Comment)) # find it in the comments

            ##### get general info

            scorebox_meta_div = soup.find('div', {'class': 'scorebox_meta'})
            if scorebox_meta_div:
               # print(f"Found scorebox_meta div for {game_id}")
               
               # Get all text content with line breaks
               full_text = scorebox_meta_div.get_text(separator='\n')
               
               # Initialize variables
               date = None
               
               # Extract date - first line is usually the date
               lines = [line.strip() for line in full_text.split('\n') if line.strip()]
               
               date = lines[0]
               # print(date)

            ##### get Passing, Rushing, & Receiving table
            player_offense_table = soup.find('table', {'id': 'player_offense'})
            if player_offense_table:
               # print('found')

               player_offense_tbody = player_offense_table.find('tbody')
               if player_offense_tbody:
                  # print(player_offense_tbody)
                  rows = player_offense_tbody.find_all('tr')

                  with open('player_offense_data.csv', 'a', newline='', encoding='utf-8') as player_offense_f:
                     player_offense_writer = csv.writer(player_offense_f)

                     for row in rows:
                        if not row.has_attr("class"):
                           player_name = row.find('th', {'data-stat': 'player'}).text

                           pass_cmp_cell = row.find('td', {'data-stat': 'pass_cmp'})
                           pass_cmp = pass_cmp_cell.get_text(strip=True) if pass_cmp_cell else 0
                           pass_att_cell = row.find('td', {'data-stat': 'pass_att'})
                           pass_att = pass_att_cell.get_text(strip=True) if pass_att_cell else 0
                           pass_yds_cell = row.find('td', {'data-stat': 'pass_yds'})
                           pass_yds = pass_yds_cell.get_text(strip=True) if pass_yds_cell else 0
                           pass_td_cell = row.find('td', {'data-stat': 'pass_td'})
                           pass_td = pass_td_cell.get_text(strip=True) if pass_td_cell else 0
                           pass_int_cell = row.find('td', {'data-stat': 'pass_int'})
                           pass_int = pass_int_cell.get_text(strip=True) if pass_int_cell else 0
                           pass_sacked_cell = row.find('td', {'data-stat': 'pass_sacked'})
                           pass_sacked = pass_sacked_cell.get_text(strip=True) if pass_sacked_cell else 0
                           pass_sacked_yds_cell = row.find('td', {'data-stat': 'pass_sacked_yds'})
                           pass_sacked_yds = pass_sacked_yds_cell.get_text(strip=True) if pass_sacked_yds_cell else 0
                           pass_long_cell = row.find('td', {'data-stat': 'pass_long'})
                           pass_long = pass_long_cell.get_text(strip=True) if pass_long_cell else 0
                           pass_rating_cell = row.find('td', {'data-stat': 'pass_rating'})
                           pass_rating = pass_rating_cell.get_text(strip=True) if pass_rating_cell else 0

                           rush_att_cell = row.find('td', {'data-stat': 'rush_att'})
                           rush_att = rush_att_cell.get_text(strip=True) if rush_att_cell else 0
                           rush_yds_cell = row.find('td', {'data-stat': 'rush_yds'})
                           rush_yds = rush_yds_cell.get_text(strip=True) if rush_yds_cell else 0
                           rush_td_cell = row.find('td', {'data-stat': 'rush_td'})
                           rush_td = rush_td_cell.get_text(strip=True) if rush_td_cell else 0
                           rush_long_cell = row.find('td', {'data-stat': 'rush_long'})
                           rush_long = rush_long_cell.get_text(strip=True) if rush_long_cell else 0

                           targets_cell = row.find('td', {'data-stat': 'targets'})
                           targets = targets_cell.get_text(strip=True) if targets_cell else 0
                           rec_cell = row.find('td', {'data-stat': 'rec'})
                           rec = rec_cell.get_text(strip=True) if rec_cell else 0
                           rec_yds_cell = row.find('td', {'data-stat': 'rec_yds'})
                           rec_yds = rec_yds_cell.get_text(strip=True) if rec_yds_cell else 0
                           rec_td_cell = row.find('td', {'data-stat': 'rec_td'})
                           rec_td = rec_td_cell.get_text(strip=True) if rec_td_cell else 0
                           rec_long_cell = row.find('td', {'data-stat': 'rec_long'})
                           rec_long = rec_long_cell.get_text(strip=True) if rec_long_cell else 0

                           fumbles_cell = row.find('td', {'data-stat': 'fumbles'})
                           fumbles = fumbles_cell.get_text(strip=True) if fumbles_cell else 0
                           fumbles_lost_cell = row.find('td', {'data-stat': 'fumbles_lost'})
                           fumbles_lost = fumbles_lost_cell.get_text(strip=True) if fumbles_lost_cell else 0

                           # print(rec_cell)

                           player_offense_writer.writerow([
                              game_id,
                              player_name,
                              date,
                              pass_cmp, pass_att, pass_yds, pass_td, pass_int, pass_sacked, pass_sacked_yds, pass_long, pass_rating,
                              rush_att, rush_yds, rush_td, rush_long,
                              targets, rec, rec_yds, rec_td, rec_long,
                              fumbles, fumbles_lost
                           ])

            ##### get Defense table
            for comment in comments:
               if 'player_defense' in comment:
                  # Parse the comment content as HTML
                  comment_soup = BeautifulSoup(comment, 'html.parser')
                  player_defense_table = comment_soup.find('table', {'id': 'player_defense'})
                  if player_defense_table:
                     # print("Found table in comments")
                     player_defense_tbody = player_defense_table.find('tbody')

                     rows = player_defense_tbody.find_all('tr')

                     with open('player_defense_data.csv', 'a', newline='', encoding='utf-8') as player_defense_f:
                        player_defense_writer = csv.writer(player_defense_f)

                        for row in rows:
                           # print(row)

                           if not row.has_attr("class"):
                              player_name = row.find('th', {'data-stat': 'player'}).text

                              def_int_cell = row.find('td', {'data-stat': 'def_int'})
                              def_int = def_int_cell.get_text(strip=True) if def_int_cell else 0
                              def_int_yds_cell = row.find('td', {'data-stat': 'def_int_yds'})
                              def_int_yds = def_int_yds_cell.get_text(strip=True) if def_int_yds_cell else 0
                              def_int_td_cell = row.find('td', {'data-stat': 'def_int_td'})
                              def_int_td = def_int_td_cell.get_text(strip=True) if def_int_td_cell else 0
                              def_int_long_cell = row.find('td', {'data-stat': 'def_int_long'})
                              def_int_long = def_int_long_cell.get_text(strip=True) if def_int_long_cell else 0
                              pass_defended_cell = row.find('td', {'data-stat': 'pass_defended'})
                              pass_defended = pass_defended_cell.get_text(strip=True) if pass_defended_cell else 0

                              sacks_cell = row.find('td', {'data-stat': 'sacks'})
                              sacks = sacks_cell.get_text(strip=True) if sacks_cell else 0
                              
                              tackles_combined_cell = row.find('td', {'data-stat': 'tackles_combined'})
                              tackles_combined = tackles_combined_cell.get_text(strip=True) if tackles_combined_cell else 0
                              tackles_solo_cell = row.find('td', {'data-stat': 'tackles_solo'})
                              tackles_solo = tackles_solo_cell.get_text(strip=True) if tackles_solo_cell else 0
                              tackles_assists_cell = row.find('td', {'data-stat': 'tackles_assists'})
                              tackles_assists = tackles_assists_cell.get_text(strip=True) if tackles_assists_cell else 0
                              tackles_loss_cell = row.find('td', {'data-stat': 'tackles_loss'})
                              tackles_loss = tackles_loss_cell.get_text(strip=True) if tackles_loss_cell else 0
                              qb_hits_cell = row.find('td', {'data-stat': 'qb_hits'})
                              qb_hits = qb_hits_cell.get_text(strip=True) if qb_hits_cell else 0

                              fumbles_rec_cell = row.find('td', {'data-stat': 'fumbles_rec'})
                              fumbles_rec = fumbles_rec_cell.get_text(strip=True) if fumbles_rec_cell else 0
                              fumbles_rec_yds_cell = row.find('td', {'data-stat': 'fumbles_rec_yds'})
                              fumbles_rec_yds = fumbles_rec_yds_cell.get_text(strip=True) if fumbles_rec_yds_cell else 0
                              fumbles_rec_td_cell = row.find('td', {'data-stat': 'fumbles_rec_td'})
                              fumbles_rec_td = fumbles_rec_td_cell.get_text(strip=True) if fumbles_rec_td_cell else 0
                              fumbles_forced_cell = row.find('td', {'data-stat': 'fumbles_forced'})
                              fumbles_forced = fumbles_forced_cell.get_text(strip=True) if fumbles_forced_cell else 0

                              player_defense_writer.writerow([
                                 game_id,
                                 player_name,
                                 date,
                                 def_int, def_int_yds, def_int_td, def_int_long, pass_defended,
                                 sacks,
                                 tackles_combined, tackles_solo, tackles_assists, tackles_loss, qb_hits,
                                 fumbles_rec, fumbles_rec_yds, fumbles_rec_td, fumbles_forced
                              ])

            ##### get Kick/Punt Returns table
            for comment in comments:
               if 'returns' in comment:
                  comment_soup = BeautifulSoup(comment, 'html.parser')
                  returns_table = comment_soup.find('table', {'id': 'returns'})
                  if player_defense_table:
                     # print("Found table in comments")
                     returns_tbody = returns_table.find('tbody')

                     rows = returns_tbody.find_all('tr')

                     with open('returns_data.csv', 'a', newline='', encoding='utf-8') as returns_f:
                        returns_writer = csv.writer(returns_f)

                        for row in rows:
                           # print(row)

                           if not row.has_attr("class"):
                              player_name = row.find('th', {'data-stat': 'player'}).text

                              kick_ret_cell = row.find('td', {'data-stat': 'kick_ret'})
                              kick_ret = kick_ret_cell.get_text(strip=True) if kick_ret_cell else 0
                              kick_ret_yds_cell = row.find('td', {'data-stat': 'kick_ret_yds'})
                              kick_ret_yds = kick_ret_yds_cell.get_text(strip=True) if kick_ret_yds_cell else 0
                              kick_ret_yds_per_ret_cell = row.find('td', {'data-stat': 'kick_ret_yds_per_ret'})
                              kick_ret_yds_per_ret = kick_ret_yds_per_ret_cell.get_text(strip=True) if kick_ret_yds_per_ret_cell else 0
                              kick_ret_td_cell = row.find('td', {'data-stat': 'kick_ret_td'})
                              kick_ret_td = kick_ret_td_cell.get_text(strip=True) if kick_ret_td_cell else 0
                              kick_ret_long_cell = row.find('td', {'data-stat': 'kick_ret_long'})
                              kick_ret_long = kick_ret_long_cell.get_text(strip=True) if kick_ret_long_cell else 0

                              punt_ret_cell = row.find('td', {'data-stat': 'punt_ret'})
                              punt_ret = punt_ret_cell.get_text(strip=True) if punt_ret_cell else 0
                              punt_ret_yds_cell = row.find('td', {'data-stat': 'punt_ret_yds'})
                              punt_ret_yds = punt_ret_yds_cell.get_text(strip=True) if punt_ret_yds_cell else 0
                              punt_ret_yds_per_ret_cell = row.find('td', {'data-stat': 'punt_ret_yds_per_ret'})
                              punt_ret_yds_per_ret = punt_ret_yds_per_ret_cell.get_text(strip=True) if punt_ret_yds_per_ret_cell else 0
                              punt_ret_td_cell = row.find('td', {'data-stat': 'punt_ret_td'})
                              punt_ret_td = punt_ret_td_cell.get_text(strip=True) if punt_ret_td_cell else 0
                              punt_ret_long_cell = row.find('td', {'data-stat': 'punt_ret_long'})
                              punt_ret_long = punt_ret_long_cell.get_text(strip=True) if punt_ret_long_cell else 0

                              returns_writer.writerow([
                                 game_id,
                                 player_name,
                                 date,
                                 kick_ret, kick_ret_yds, kick_ret_yds_per_ret, kick_ret_td, kick_ret_long,
                                 punt_ret, punt_ret_yds, punt_ret_yds_per_ret, punt_ret_td, punt_ret_long
                              ])

            ##### get Kicking & Punting table
            for comment in comments:
               if 'kicking' in comment:
                  comment_soup = BeautifulSoup(comment, 'html.parser')
                  kicking_table = comment_soup.find('table', {'id': 'kicking'})
                  if kicking_table:
                     # print("Found table in comments")
                     kicking_tbody = kicking_table.find('tbody')

                     rows = kicking_tbody.find_all('tr')

                     with open('kicking_data.csv', 'a', newline='', encoding='utf-8') as kicking_f:
                        kicking_writer = csv.writer(kicking_f)

                        for row in rows:
                           # print(row)

                           if not row.has_attr("class"):
                              player_name = row.find('th', {'data-stat': 'player'}).text

                              xpm_cell = row.find('td', {'data-stat': 'xpm'})
                              xpm = xpm_cell.get_text(strip=True) if xpm_cell else 0
                              xpa_cell = row.find('td', {'data-stat': 'xpa'})
                              xpa = xpa_cell.get_text(strip=True) if xpa_cell else 0

                              fgm_cell = row.find('td', {'data-stat': 'fgm'})
                              fgm = fgm_cell.get_text(strip=True) if fgm_cell else 0
                              fga_cell = row.find('td', {'data-stat': 'fga'})
                              fga = fga_cell.get_text(strip=True) if fga_cell else 0

                              punt_cell = row.find('td', {'data-stat': 'punt'})
                              punt = punt_cell.get_text(strip=True) if punt_cell else 0
                              punt_yds_cell = row.find('td', {'data-stat': 'punt_yds'})
                              punt_yds = punt_yds_cell.get_text(strip=True) if punt_yds_cell else 0
                              punt_yds_per_punt_cell = row.find('td', {'data-stat': 'punt_yds_per_punt'})
                              punt_yds_per_punt = punt_yds_per_punt_cell.get_text(strip=True) if punt_yds_per_punt_cell else 0
                              punt_long_cell = row.find('td', {'data-stat': 'punt_long'})
                              punt_long = punt_long_cell.get_text(strip=True) if punt_long_cell else 0

                              kicking_writer.writerow([
                                 game_id,
                                 player_name,
                                 date,
                                 xpm, xpa,
                                 fgm, fga,
                                 punt, punt_yds, punt_yds_per_punt, punt_long
                              ])

            ##### get Advanced Passing table
            for comment in comments:
               if 'passing_advanced' in comment:
                  comment_soup = BeautifulSoup(comment, 'html.parser')
                  passing_advanced_table = comment_soup.find('table', {'id': 'passing_advanced'})
                  if passing_advanced_table:
                     # print("Found table in com/mentsasdfasdf")
                     passing_advanced_tbody = passing_advanced_table.find('tbody')

                     rows = passing_advanced_tbody.find_all('tr')

                     with open('passing_advanced_data.csv', 'a', newline='', encoding='utf-8') as passing_advanced_f:
                        passing_advanced_writer = csv.writer(passing_advanced_f)

                        for row in rows:
                           # print(row)

                           if not row.has_attr("class"):
                              player_name = row.find('th', {'data-stat': 'player'}).text

                              pass_cmp_cell = row.find('td', {'data-stat': 'pass_cmp'})
                              pass_cmp = pass_cmp_cell.get_text(strip=True) if pass_cmp_cell else 0
                              pass_att_cell = row.find('td', {'data-stat': 'pass_att'})
                              pass_att = pass_att_cell.get_text(strip=True) if pass_att_cell else 0
                              pass_yds_cell = row.find('td', {'data-stat': 'pass_yds'})
                              pass_yds = pass_yds_cell.get_text(strip=True) if pass_yds_cell else 0

                              pass_first_down_cell = row.find('td', {'data-stat': 'pass_first_down'})
                              pass_first_down = pass_first_down_cell.get_text(strip=True) if pass_first_down_cell else 0
                              pass_first_down_pct_cell = row.find('td', {'data-stat': 'pass_first_down_pct'})
                              pass_first_down_pct = pass_first_down_pct_cell.get_text(strip=True) if pass_first_down_pct_cell else 0

                              pass_target_yds_cell = row.find('td', {'data-stat': 'pass_target_yds'})
                              pass_target_yds = pass_target_yds_cell.get_text(strip=True) if pass_target_yds_cell else 0
                              pass_tgt_yds_per_att_cell = row.find('td', {'data-stat': 'pass_tgt_yds_per_att'})
                              pass_tgt_yds_per_att = pass_tgt_yds_per_att_cell.get_text(strip=True) if pass_tgt_yds_per_att_cell else 0

                              pass_air_yds_cell = row.find('td', {'data-stat': 'pass_air_yds'})
                              pass_air_yds = pass_air_yds_cell.get_text(strip=True) if pass_air_yds_cell else 0
                              pass_air_yds_per_cmp_cell = row.find('td', {'data-stat': 'pass_air_yds_per_cmp'})
                              pass_air_yds_per_cmp = pass_air_yds_per_cmp_cell.get_text(strip=True) if pass_air_yds_per_cmp_cell else 0
                              pass_air_yds_per_att_cell = row.find('td', {'data-stat': 'pass_air_yds_per_att'})
                              pass_air_yds_per_att = pass_air_yds_per_att_cell.get_text(strip=True) if pass_air_yds_per_att_cell else 0

                              pass_yac_cell = row.find('td', {'data-stat': 'pass_yac'})
                              pass_yac = pass_yac_cell.get_text(strip=True) if pass_yac_cell else 0
                              pass_yac_per_cmp_cell = row.find('td', {'data-stat': 'pass_yac_per_cmp'})
                              pass_yac_per_cmp = pass_yac_per_cmp_cell.get_text(strip=True) if pass_yac_per_cmp_cell else 0

                              pass_drops_cell = row.find('td', {'data-stat': 'pass_drops'})
                              pass_drops = pass_drops_cell.get_text(strip=True) if pass_drops_cell else 0
                              pass_drop_pct_cell = row.find('td', {'data-stat': 'pass_drop_pct'})
                              pass_drop_pct = pass_drop_pct_cell.get_text(strip=True) if pass_drop_pct_cell else 0

                              pass_poor_throws_cell = row.find('td', {'data-stat': 'pass_poor_throws'})
                              pass_poor_throws = pass_poor_throws_cell.get_text(strip=True) if pass_poor_throws_cell else 0
                              pass_poor_throw_pct_cell = row.find('td', {'data-stat': 'pass_poor_throw_pct'})
                              pass_poor_throw_pct = pass_poor_throw_pct_cell.get_text(strip=True) if pass_poor_throw_pct_cell else 0

                              pass_sacked_cell = row.find('td', {'data-stat': 'pass_sacked'})
                              pass_sacked = pass_sacked_cell.get_text(strip=True) if pass_sacked_cell else 0
                              pass_blitzed_cell = row.find('td', {'data-stat': 'pass_blitzed'})
                              pass_blitzed = pass_blitzed_cell.get_text(strip=True) if pass_blitzed_cell else 0
                              pass_hurried_cell = row.find('td', {'data-stat': 'pass_hurried'})
                              pass_hurried = pass_hurried_cell.get_text(strip=True) if pass_hurried_cell else 0
                              pass_hits_cell = row.find('td', {'data-stat': 'pass_hits'})
                              pass_hits = pass_hits_cell.get_text(strip=True) if pass_hits_cell else 0
                              pass_pressured_cell = row.find('td', {'data-stat': 'pass_pressured'})
                              pass_pressured = pass_pressured_cell.get_text(strip=True) if pass_pressured_cell else 0
                              pass_pressured_pct_cell = row.find('td', {'data-stat': 'pass_pressured_pct'})
                              pass_pressured_pct = pass_pressured_pct_cell.get_text(strip=True) if pass_pressured_pct_cell else 0

                              rush_scrambles_cell = row.find('td', {'data-stat': 'rush_scrambles'})
                              rush_scrambles = rush_scrambles_cell.get_text(strip=True) if rush_scrambles_cell else 0
                              rush_scrambles_yds_per_att_cell = row.find('td', {'data-stat': 'rush_scrambles_yds_per_att'})
                              rush_scrambles_yds_per_att = rush_scrambles_yds_per_att_cell.get_text(strip=True) if rush_scrambles_yds_per_att_cell else 0

                              passing_advanced_writer.writerow([
                                 game_id,
                                 player_name,
                                 date,
                                 pass_cmp, pass_att, pass_yds,
                                 pass_first_down, pass_first_down_pct,
                                 pass_target_yds, pass_tgt_yds_per_att,
                                 pass_air_yds, pass_air_yds_per_cmp, pass_air_yds_per_att,
                                 pass_yac, pass_yac_per_cmp,
                                 pass_drops, pass_drop_pct,
                                 pass_poor_throws, pass_poor_throw_pct,
                                 pass_sacked, pass_blitzed, pass_hurried, pass_hits, pass_pressured, pass_pressured_pct,
                                 rush_scrambles, rush_scrambles_yds_per_att
                              ])

            ##### get Advanced Rushing table
            for comment in comments:
               if 'rushing_advanced' in comment:
                  comment_soup = BeautifulSoup(comment, 'html.parser')
                  rushing_advanced_table = comment_soup.find('table', {'id': 'rushing_advanced'})
                  if rushing_advanced_table:
                     # print("Found table in com/mentsasdfasdf")
                     rushing_advanced_tbody = rushing_advanced_table.find('tbody')

                     rows = rushing_advanced_tbody.find_all('tr')

                     with open('rushing_advanced_data.csv', 'a', newline='', encoding='utf-8') as rushing_advanced_f:
                        rushing_advanced_writer = csv.writer(rushing_advanced_f)

                        for row in rows:
                           # print(row)

                           if not row.has_attr("class"):
                              player_name = row.find('th', {'data-stat': 'player'}).text

                              rush_att_cell = row.find('td', {'data-stat': 'rush_att'})
                              rush_att = rush_att_cell.get_text(strip=True) if rush_att_cell else 0
                              rush_yds_cell = row.find('td', {'data-stat': 'rush_yds'})
                              rush_yds = rush_yds_cell.get_text(strip=True) if rush_yds_cell else 0
                              rush_td_cell = row.find('td', {'data-stat': 'rush_td'})
                              rush_td = rush_td_cell.get_text(strip=True) if rush_td_cell else 0

                              rush_first_down_cell = row.find('td', {'data-stat': 'rush_first_down'})
                              rush_first_down = rush_first_down_cell.get_text(strip=True) if rush_first_down_cell else 0

                              rush_yds_before_contact_cell = row.find('td', {'data-stat': 'rush_yds_before_contact'})
                              rush_yds_before_contact = rush_yds_before_contact_cell.get_text(strip=True) if rush_yds_before_contact_cell else 0
                              rush_yds_bc_per_rush_cell = row.find('td', {'data-stat': 'rush_yds_bc_per_rush'})
                              rush_yds_bc_per_rush = rush_yds_bc_per_rush_cell.get_text(strip=True) if rush_yds_bc_per_rush_cell else 0

                              rush_yac_cell = row.find('td', {'data-stat': 'rush_yac'})
                              rush_yac = rush_yac_cell.get_text(strip=True) if rush_yac_cell else 0
                              rush_yac_per_rush_cell = row.find('td', {'data-stat': 'rush_yac_per_rush'})
                              rush_yac_per_rush = rush_yac_per_rush_cell.get_text(strip=True) if rush_yac_per_rush_cell else 0

                              rush_broken_tackles_cell = row.find('td', {'data-stat': 'rush_broken_tackles'})
                              rush_broken_tackles = rush_broken_tackles_cell.get_text(strip=True) if rush_broken_tackles_cell else 0
                              rush_broken_tackles_per_rush_cell = row.find('td', {'data-stat': 'rush_broken_tackles_per_rush'})
                              rush_broken_tackles_per_rush = rush_broken_tackles_per_rush_cell.get_text(strip=True) if rush_broken_tackles_per_rush_cell else 0

                              rushing_advanced_writer.writerow([
                                 game_id,
                                 player_name,
                                 date,
                                 rush_att, rush_yds, rush_td,
                                 rush_first_down,
                                 rush_yds_before_contact, rush_yds_bc_per_rush,
                                 rush_yac, rush_yac_per_rush,
                                 rush_broken_tackles, rush_broken_tackles_per_rush
                              ])

            ##### get Advanced Receiving table
            for comment in comments:
               if 'receiving_advanced' in comment: 
                  comment_soup = BeautifulSoup(comment, 'html.parser')
                  receiving_advanced_table = comment_soup.find('table', {'id': 'receiving_advanced'})  
                  if receiving_advanced_table:
                        # print("Found receiving table in comments")
                        receiving_advanced_tbody = receiving_advanced_table.find('tbody')

                        rows = receiving_advanced_tbody.find_all('tr')

                        with open('receiving_advanced_data.csv', 'a', newline='', encoding='utf-8') as receiving_advanced_f:  
                           receiving_advanced_writer = csv.writer(receiving_advanced_f)  

                           for row in rows:
                              # print(row)

                              if not row.has_attr("class"):
                                    player_name = row.find('th', {'data-stat': 'player'}).text

                                    targets_cell = row.find('td', {'data-stat': 'targets'})
                                    targets = targets_cell.get_text(strip=True) if targets_cell else 0                                 
                                    rec_cell = row.find('td', {'data-stat': 'rec'})
                                    rec = rec_cell.get_text(strip=True) if rec_cell else 0                                   
                                    rec_yds_cell = row.find('td', {'data-stat': 'rec_yds'})
                                    rec_yds = rec_yds_cell.get_text(strip=True) if rec_yds_cell else 0                                  
                                    rec_td_cell = row.find('td', {'data-stat': 'rec_td'})
                                    rec_td = rec_td_cell.get_text(strip=True) if rec_td_cell else 0

                                    rec_first_down_cell = row.find('td', {'data-stat': 'rec_first_down'})
                                    rec_first_down = rec_first_down_cell.get_text(strip=True) if rec_first_down_cell else 0

                                    rec_air_yds_cell = row.find('td', {'data-stat': 'rec_air_yds'})
                                    rec_air_yds = rec_air_yds_cell.get_text(strip=True) if rec_air_yds_cell else 0
                                    rec_air_yds_per_rec_cell = row.find('td', {'data-stat': 'rec_air_yds_per_rec'})
                                    rec_air_yds_per_rec = rec_air_yds_per_rec_cell.get_text(strip=True) if rec_air_yds_per_rec_cell else 0

                                    rec_yac_cell = row.find('td', {'data-stat': 'rec_yac'})
                                    rec_yac = rec_yac_cell.get_text(strip=True) if rec_yac_cell else 0
                                    rec_yac_per_rec_cell = row.find('td', {'data-stat': 'rec_yac_per_rec'})
                                    rec_yac_per_rec = rec_yac_per_rec_cell.get_text(strip=True) if rec_yac_per_rec_cell else 0

                                    rec_adot_cell = row.find('td', {'data-stat': 'rec_adot'})
                                    rec_adot = rec_adot_cell.get_text(strip=True) if rec_adot_cell else 0

                                    rec_broken_tackles_cell = row.find('td', {'data-stat': 'rec_broken_tackles'})
                                    rec_broken_tackles = rec_broken_tackles_cell.get_text(strip=True) if rec_broken_tackles_cell else 0
                                    rec_broken_tackles_per_rec_cell = row.find('td', {'data-stat': 'rec_broken_tackles_per_rec'})
                                    rec_broken_tackles_per_rec = rec_broken_tackles_per_rec_cell.get_text(strip=True) if rec_broken_tackles_per_rec_cell else 0

                                    rec_drops_cell = row.find('td', {'data-stat': 'rec_drops'})
                                    rec_drops = rec_drops_cell.get_text(strip=True) if rec_drops_cell else 0
                                    rec_drop_pct_cell = row.find('td', {'data-stat': 'rec_drop_pct'})
                                    rec_drop_pct = rec_drop_pct_cell.get_text(strip=True) if rec_drop_pct_cell else 0

                                    rec_target_int_cell = row.find('td', {'data-stat': 'rec_target_int'})
                                    rec_target_int = rec_target_int_cell.get_text(strip=True) if rec_target_int_cell else 0

                                    rec_pass_rating_cell = row.find('td', {'data-stat': 'rec_pass_rating'})
                                    rec_pass_rating = rec_pass_rating_cell.get_text(strip=True) if rec_pass_rating_cell else 0

                                    receiving_advanced_writer.writerow([
                                       game_id,
                                       player_name,
                                       date,
                                       targets, rec, rec_yds, rec_td,
                                       rec_first_down,
                                       rec_air_yds, rec_air_yds_per_rec,
                                       rec_yac, rec_yac_per_rec,
                                       rec_adot,
                                       rec_broken_tackles, rec_broken_tackles_per_rec,
                                       rec_drops, rec_drop_pct,
                                       rec_target_int,
                                       rec_pass_rating
                                    ])

            ##### get Advanced Defense table
            for comment in comments:
               if 'defense_advanced' in comment:
                  comment_soup = BeautifulSoup(comment, 'html.parser')
                  defense_advanced_table = comment_soup.find('table', {'id': 'defense_advanced'})
                  if defense_advanced_table:
                        # print("Found defensive table in comments")
                        defense_advanced_tbody = defense_advanced_table.find('tbody')

                        rows = defense_advanced_tbody.find_all('tr')

                        with open('defense_advanced_data.csv', 'a', newline='', encoding='utf-8') as defense_advanced_f:
                           defense_advanced_writer = csv.writer(defense_advanced_f)

                           for row in rows:
                              # print(row)

                              if not row.has_attr("class"):
                                    player_name = row.find('th', {'data-stat': 'player'}).text

                                    def_int_cell = row.find('td', {'data-stat': 'def_int'})
                                    def_int = def_int_cell.get_text(strip=True) if def_int_cell else 0

                                    def_targets_cell = row.find('td', {'data-stat': 'def_targets'})
                                    def_targets = def_targets_cell.get_text(strip=True) if def_targets_cell else 0
                                    def_cmp_cell = row.find('td', {'data-stat': 'def_cmp'})
                                    def_cmp = def_cmp_cell.get_text(strip=True) if def_cmp_cell else 0
                                    def_cmp_perc_cell = row.find('td', {'data-stat': 'def_cmp_perc'})
                                    def_cmp_perc = def_cmp_perc_cell.get_text(strip=True) if def_cmp_perc_cell else 0
                                    def_cmp_yds_cell = row.find('td', {'data-stat': 'def_cmp_yds'})
                                    def_cmp_yds = def_cmp_yds_cell.get_text(strip=True) if def_cmp_yds_cell else 0
                                    def_yds_per_cmp_cell = row.find('td', {'data-stat': 'def_yds_per_cmp'})
                                    def_yds_per_cmp = def_yds_per_cmp_cell.get_text(strip=True) if def_yds_per_cmp_cell else 0
                                    def_yds_per_target_cell = row.find('td', {'data-stat': 'def_yds_per_target'})
                                    def_yds_per_target = def_yds_per_target_cell.get_text(strip=True) if def_yds_per_target_cell else 0
                                    def_cmp_td_cell = row.find('td', {'data-stat': 'def_cmp_td'})
                                    def_cmp_td = def_cmp_td_cell.get_text(strip=True) if def_cmp_td_cell else 0

                                    def_pass_rating_cell = row.find('td', {'data-stat': 'def_pass_rating'})
                                    def_pass_rating = def_pass_rating_cell.get_text(strip=True) if def_pass_rating_cell else 0

                                    def_tgt_yds_per_att_cell = row.find('td', {'data-stat': 'def_tgt_yds_per_att'})
                                    def_tgt_yds_per_att = def_tgt_yds_per_att_cell.get_text(strip=True) if def_tgt_yds_per_att_cell else 0
                                    def_air_yds_cell = row.find('td', {'data-stat': 'def_air_yds'})
                                    def_air_yds = def_air_yds_cell.get_text(strip=True) if def_air_yds_cell else 0
                                    def_yac_cell = row.find('td', {'data-stat': 'def_yac'})
                                    def_yac = def_yac_cell.get_text(strip=True) if def_yac_cell else 0

                                    blitzes_cell = row.find('td', {'data-stat': 'blitzes'})
                                    blitzes = blitzes_cell.get_text(strip=True) if blitzes_cell else 0
                                    qb_hurry_cell = row.find('td', {'data-stat': 'qb_hurry'})
                                    qb_hurry = qb_hurry_cell.get_text(strip=True) if qb_hurry_cell else 0
                                    qb_knockdown_cell = row.find('td', {'data-stat': 'qb_knockdown'})
                                    qb_knockdown = qb_knockdown_cell.get_text(strip=True) if qb_knockdown_cell else 0
                                    sacks_cell = row.find('td', {'data-stat': 'sacks'})
                                    sacks = sacks_cell.get_text(strip=True) if sacks_cell else 0
                                    pressures_cell = row.find('td', {'data-stat': 'pressures'})
                                    pressures = pressures_cell.get_text(strip=True) if pressures_cell else 0

                                    tackles_combined_cell = row.find('td', {'data-stat': 'tackles_combined'})
                                    tackles_combined = tackles_combined_cell.get_text(strip=True) if tackles_combined_cell else 0
                                    tackles_missed_cell = row.find('td', {'data-stat': 'tackles_missed'})
                                    tackles_missed = tackles_missed_cell.get_text(strip=True) if tackles_missed_cell else 0
                                    tackles_missed_pct_cell = row.find('td', {'data-stat': 'tackles_missed_pct'})
                                    tackles_missed_pct = tackles_missed_pct_cell.get_text(strip=True) if tackles_missed_pct_cell else 0

                                    defense_advanced_writer.writerow([
                                       game_id,
                                       player_name,
                                       date,
                                       def_int,
                                       def_targets, def_cmp, def_cmp_perc, def_cmp_yds, 
                                       def_yds_per_cmp, def_yds_per_target, def_cmp_td,
                                       def_pass_rating,
                                       def_tgt_yds_per_att, def_air_yds, def_yac,
                                       blitzes, qb_hurry, qb_knockdown, sacks, pressures,
                                       tackles_combined, tackles_missed, tackles_missed_pct
                                    ])

            ##### get Starters
            for comment in comments:
               if 'home_starters' in comment:
                  comment_soup = BeautifulSoup(comment, 'html.parser')
                  home_starters_table = comment_soup.find('table', {'id': 'home_starters'})
                  if home_starters_table:
                     # print("Found table in comments")
                     home_starters_tbody = home_starters_table.find('tbody')

                     rows = home_starters_tbody.find_all('tr')

                     with open('starters_data.csv', 'a', newline='', encoding='utf-8') as starters_f:
                        starters_writer = csv.writer(starters_f)

                        for row in rows:
                           # print(row)

                           if not row.has_attr("class"):
                              player_name = row.find('th', {'data-stat': 'player'}).text

                              starters_writer.writerow([
                                 game_id,
                                 player_name,
                                 date,
                                 True
                              ])

               if 'vis_starters' in comment:
                  comment_soup = BeautifulSoup(comment, 'html.parser')
                  vis_starters_table = comment_soup.find('table', {'id': 'vis_starters'})
                  if home_starters_table:
                     # print("Found table in comments")
                     vis_starters_tbody = vis_starters_table.find('tbody')

                     rows = vis_starters_tbody.find_all('tr')

                     with open('starters_data.csv', 'a', newline='', encoding='utf-8') as starters_f:
                        starters_writer = csv.writer(starters_f)

                        for row in rows:
                           # print(row)

                           if not row.has_attr("class"):
                              player_name = row.find('th', {'data-stat': 'player'}).text

                              starters_writer.writerow([
                                 game_id,
                                 player_name,
                                 date,
                                 True
                              ])
            
         elif response.status_code == 429:
            # time.sleep(random.uniform(2, 4))
            print("429 error at " + game_id)
            game_id_429 = game_id
            break

         else:
            print(f"Failed with status: {response.status_code}")
            failed_ids.append(game_id)
               
      except Exception as e:
         print(f"Error: {e}")
         failed_ids.append(game_id)

      # with open('player_snap_data.csv', 'a', newline='', encoding='utf-8') as f:
      #       writer = csv.writer(f)

   
      # break

get_data(game_id_list)
# get_data(['202509040phi'])
# Out:
# Processing: https://www.pro-football-reference.com/boxscores/201609080den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609080den.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609110crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609110crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609120was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609120was.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609120sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609120sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609150buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609150buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180det.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180car.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180was.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180den.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609180min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609180min.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609190chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609190chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609220nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609220nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250car.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609250dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609250dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609260nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609260nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/201609290cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201609290cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020was.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610020pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610020pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610030min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610030min.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610060sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610060sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090det.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090min.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090den.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610090gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610090gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610100car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610100car.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610130sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610130sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160det.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160was.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610160htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610160htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610170crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610170crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610200gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610200gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230det.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610230crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610230crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610240den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610240den.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610270oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610270oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300car.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300den.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610300dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610300dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/201610310chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201610310chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611030tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611030tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060min.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611060rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611060rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611070sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611070sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611100rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611100rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130car.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130was.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611130nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611130nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611140nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611140nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611170car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611170car.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200min.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200det.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611200was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611200was.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611210rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611210rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611240det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611240det.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611240dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611240dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611240clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611240clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611270den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611270den.htm
# Processing: https://www.pro-football-reference.com/boxscores/201611280phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201611280phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612010min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612010min.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612040sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612040sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612050nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612050nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612080kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612080kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110car.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110det.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612110nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612110nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612120nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612120nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612150sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612150sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612170nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612170nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180min.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180den.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612180dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612180dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612190was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612190was.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612220phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612220phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240car.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612240htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612240htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612250pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612250pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612250kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612250kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/201612260dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201612260dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010min.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010den.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010was.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701010det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701010det.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701070htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701070htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701070sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701070sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701080pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701080pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701080gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701080gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701140atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701140atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701140nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701140nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701150dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/201701150dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/201701150kan.htm
# Status code: 200
# ...
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511230det.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511230gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511230gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511230rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511230rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511230oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511230oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511230rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511230rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511230crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511230crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511230nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511230nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511230dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511230dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511230ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511230ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511240sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511240sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511270det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511270det.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511270dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511270dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511270rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511270rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511280phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511280phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300car.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/202511300was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202511300was.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512010nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512010nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512040det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512040det.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070atl.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070min.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512070kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512070kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512080sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512080sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512110tam.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512110tam.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140nwe.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140nwe.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140jax.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140jax.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140phi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140phi.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140den.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140ram.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140ram.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512140dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512140dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512150pit.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512150pit.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512180sea.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512180sea.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512200was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512200was.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512200chi.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512200chi.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210car.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210dal.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210dal.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210nyg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210nyg.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210nor.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210nor.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210crd.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210crd.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210den.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210den.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210det.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210det.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210htx.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210htx.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512210rav.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512210rav.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512220clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512220clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512250was.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512250was.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512250min.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512250min.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512250kan.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512250kan.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512270sdg.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512270sdg.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512270gnb.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512270gnb.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280car.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280car.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280cin.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280cin.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280cle.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280cle.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280clt.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280clt.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280mia.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280mia.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280oti.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280oti.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280nyj.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280nyj.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280rai.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280rai.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280buf.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280buf.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512280sfo.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512280sfo.htm
# Processing: https://www.pro-football-reference.com/boxscores/202512290atl.htm
# Status code: 200
# Successfully fetched https://www.pro-football-reference.com/boxscores/202512290atl.htm

# %%
# combine the csvs

# all snap data
player_snap_df = pd.read_csv('player_snap_data.csv')

player_offense_df = pd.read_csv('player_offense_data.csv')
player_defense_df = pd.read_csv('player_defense_data.csv')
kicking_df = pd.read_csv('kicking_data.csv')
returns_df = pd.read_csv('returns_data.csv')
passing_advanced_df = pd.read_csv('passing_advanced_data.csv')
rushing_advanced_df = pd.read_csv('rushing_advanced_data.csv')
receiving_advanced_df = pd.read_csv('receiving_advanced_data.csv')
defense_advanced_df = pd.read_csv('defense_advanced_data.csv')

# %%
# defense_advanced_df

from functools import reduce

# Create list of all DataFrames
all_dfs = [
    player_snap_df,
    player_offense_df,
    player_defense_df,
    kicking_df,
    returns_df,
    passing_advanced_df,
    rushing_advanced_df,
    receiving_advanced_df,
    defense_advanced_df
]

# Define merge function
def merge_dfs(left, right):
    return pd.merge(left, right, on=['game_id', 'player_name', 'date'], how='left')

# Reduce all DataFrames
combined_df = reduce(merge_dfs, all_dfs)

combined_df.to_csv('combined_data.csv', index=False)

# %%
combined_data = pd.read_csv('combined_data.csv')
# combined_data

for column in combined_data.columns:
    print(combined_data[column].unique())
# Out:
# C:\Users\bchm5\AppData\Local\Temp\ipykernel_18924\1775109482.py:1: DtypeWarning: Columns (13,81,83,89,121,137) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_data = pd.read_csv('combined_data.csv')
# ['201609080den' '201609110rav' '201609110jax' ... '202101240gnb'
#  '202101240kan' '202102070tam']
# ['Michael Schofield' 'Matt Paradis' 'Russell Okung' ...
#  'Cedrick Lattimore' 'Blake Hance' 'Javon Hagan']
# ['Thursday Sep 8, 2016' 'Sunday Sep 11, 2016' 'Monday Sep 12, 2016'
#  'Thursday Sep 15, 2016' 'Sunday Sep 18, 2016' 'Monday Sep 19, 2016'
#  'Thursday Sep 22, 2016' 'Sunday Sep 25, 2016' 'Monday Sep 26, 2016'
#  'Thursday Sep 29, 2016' 'Sunday Oct 2, 2016' 'Monday Oct 3, 2016'
#  'Thursday Oct 6, 2016' 'Sunday Oct 9, 2016' 'Monday Oct 10, 2016'
#  'Thursday Oct 13, 2016' 'Sunday Oct 16, 2016' 'Monday Oct 17, 2016'
#  'Thursday Oct 20, 2016' 'Sunday Oct 23, 2016' 'Monday Oct 24, 2016'
#  'Thursday Oct 27, 2016' 'Sunday Oct 30, 2016' 'Monday Oct 31, 2016'
#  'Thursday Nov 3, 2016' 'Sunday Nov 6, 2016' 'Monday Nov 7, 2016'
#  'Thursday Nov 10, 2016' 'Sunday Nov 13, 2016' 'Monday Nov 14, 2016'
#  'Thursday Nov 17, 2016' 'Sunday Nov 20, 2016' 'Monday Nov 21, 2016'
#  'Thursday Nov 24, 2016' 'Sunday Nov 27, 2016' 'Monday Nov 28, 2016'
#  'Thursday Dec 1, 2016' 'Sunday Dec 4, 2016' 'Monday Dec 5, 2016'
#  'Thursday Dec 8, 2016' 'Sunday Dec 11, 2016' 'Monday Dec 12, 2016'
#  'Thursday Dec 15, 2016' 'Saturday Dec 17, 2016' 'Sunday Dec 18, 2016'
#  'Monday Dec 19, 2016' 'Thursday Dec 22, 2016' 'Saturday Dec 24, 2016'
#  'Sunday Dec 25, 2016' 'Monday Dec 26, 2016' 'Sunday Jan 1, 2017'
#  'Saturday Jan 7, 2017' 'Sunday Jan 8, 2017' 'Saturday Jan 14, 2017'
#  'Sunday Jan 15, 2017' 'Sunday Jan 22, 2017' 'Sunday Feb 5, 2017'
#  'Thursday Sep 7, 2017' 'Sunday Sep 10, 2017' 'Monday Sep 11, 2017'
#  'Thursday Sep 14, 2017' 'Sunday Sep 17, 2017' 'Monday Sep 18, 2017'
#  'Thursday Sep 21, 2017' 'Sunday Sep 24, 2017' 'Monday Sep 25, 2017'
#  'Thursday Sep 28, 2017' 'Sunday Oct 1, 2017' 'Monday Oct 2, 2017'
#  'Thursday Oct 5, 2017' 'Sunday Oct 8, 2017' 'Monday Oct 9, 2017'
#  'Thursday Oct 12, 2017' 'Sunday Oct 15, 2017' 'Monday Oct 16, 2017'
#  'Thursday Oct 19, 2017' 'Sunday Oct 22, 2017' 'Monday Oct 23, 2017'
#  'Thursday Oct 26, 2017' 'Sunday Oct 29, 2017' 'Monday Oct 30, 2017'
#  'Thursday Nov 2, 2017' 'Sunday Nov 5, 2017' 'Monday Nov 6, 2017'
#  'Thursday Nov 9, 2017' 'Sunday Nov 12, 2017' 'Monday Nov 13, 2017'
#  'Thursday Nov 16, 2017' 'Sunday Nov 19, 2017' 'Monday Nov 20, 2017'
#  'Thursday Nov 23, 2017' 'Sunday Nov 26, 2017' 'Monday Nov 27, 2017'
#  'Thursday Nov 30, 2017' 'Sunday Dec 3, 2017' 'Monday Dec 4, 2017'
#  'Thursday Dec 7, 2017' 'Sunday Dec 10, 2017' 'Monday Dec 11, 2017'
#  'Thursday Dec 14, 2017' 'Saturday Dec 16, 2017' 'Sunday Dec 17, 2017'
#  'Monday Dec 18, 2017' 'Saturday Dec 23, 2017' 'Sunday Dec 24, 2017'
#  'Monday Dec 25, 2017' 'Sunday Dec 31, 2017' 'Saturday Jan 6, 2018'
#  'Sunday Jan 7, 2018' 'Saturday Jan 13, 2018' 'Sunday Jan 14, 2018'
#  'Sunday Jan 21, 2018' 'Sunday Feb 4, 2018' 'Thursday Sep 6, 2018'
#  'Sunday Sep 9, 2018' 'Monday Sep 10, 2018' 'Thursday Sep 13, 2018'
#  'Sunday Sep 16, 2018' 'Monday Sep 17, 2018' 'Thursday Sep 20, 2018'
#  'Sunday Sep 23, 2018' 'Monday Sep 24, 2018' 'Thursday Sep 27, 2018'
#  'Sunday Sep 30, 2018' 'Monday Oct 1, 2018' 'Thursday Oct 4, 2018'
#  'Sunday Oct 7, 2018' 'Monday Oct 8, 2018' 'Thursday Oct 11, 2018'
#  'Sunday Oct 14, 2018' 'Monday Oct 15, 2018' 'Thursday Oct 18, 2018'
#  'Sunday Oct 21, 2018' 'Monday Oct 22, 2018' 'Thursday Oct 25, 2018'
#  'Sunday Oct 28, 2018' 'Monday Oct 29, 2018' 'Thursday Nov 1, 2018'
#  'Sunday Nov 4, 2018' 'Monday Nov 5, 2018' 'Thursday Nov 8, 2018'
#  'Sunday Nov 11, 2018' 'Monday Nov 12, 2018' 'Thursday Nov 15, 2018'
#  'Sunday Nov 18, 2018' 'Monday Nov 19, 2018' 'Thursday Nov 22, 2018'
#  'Sunday Nov 25, 2018' 'Monday Nov 26, 2018' 'Thursday Nov 29, 2018'
#  'Sunday Dec 2, 2018' 'Monday Dec 3, 2018' 'Thursday Dec 6, 2018'
#  'Sunday Dec 9, 2018' 'Monday Dec 10, 2018' 'Thursday Dec 13, 2018'
#  'Saturday Dec 15, 2018' 'Sunday Dec 16, 2018' 'Monday Dec 17, 2018'
#  'Saturday Dec 22, 2018' 'Sunday Dec 23, 2018' 'Monday Dec 24, 2018'
#  'Sunday Dec 30, 2018' 'Saturday Jan 5, 2019' 'Sunday Jan 6, 2019'
#  'Saturday Jan 12, 2019' 'Sunday Jan 13, 2019' 'Sunday Jan 20, 2019'
#  'Sunday Feb 3, 2019' 'Thursday Sep 5, 2019' 'Sunday Sep 8, 2019'
#  'Monday Sep 9, 2019' 'Thursday Sep 12, 2019' 'Sunday Sep 15, 2019'
#  'Monday Sep 16, 2019' 'Thursday Sep 19, 2019' 'Sunday Sep 22, 2019'
#  'Monday Sep 23, 2019' 'Thursday Sep 26, 2019' 'Sunday Sep 29, 2019'
#  'Monday Sep 30, 2019' 'Thursday Oct 3, 2019' 'Sunday Oct 6, 2019'
#  'Monday Oct 7, 2019' 'Thursday Oct 10, 2019' 'Sunday Oct 13, 2019'
#  'Monday Oct 14, 2019' 'Thursday Oct 17, 2019' 'Sunday Oct 20, 2019'
#  'Monday Oct 21, 2019' 'Thursday Oct 24, 2019' 'Sunday Oct 27, 2019'
#  'Monday Oct 28, 2019' 'Thursday Oct 31, 2019' 'Sunday Nov 3, 2019'
#  'Monday Nov 4, 2019' 'Thursday Nov 7, 2019' 'Sunday Nov 10, 2019'
#  'Monday Nov 11, 2019' 'Thursday Nov 14, 2019' 'Sunday Nov 17, 2019'
#  'Monday Nov 18, 2019' 'Thursday Nov 21, 2019' 'Sunday Nov 24, 2019'
#  'Monday Nov 25, 2019' 'Thursday Nov 28, 2019' 'Sunday Dec 1, 2019'
#  'Monday Dec 2, 2019' 'Thursday Dec 5, 2019' 'Sunday Dec 8, 2019'
#  'Monday Dec 9, 2019' 'Thursday Dec 12, 2019' 'Sunday Dec 15, 2019'
#  'Monday Dec 16, 2019' 'Saturday Dec 21, 2019' 'Sunday Dec 22, 2019'
#  'Monday Dec 23, 2019' 'Sunday Dec 29, 2019' 'Saturday Jan 4, 2020'
#  'Sunday Jan 5, 2020' 'Saturday Jan 11, 2020' 'Sunday Jan 12, 2020'
#  'Sunday Jan 19, 2020' 'Sunday Feb 2, 2020' 'Thursday Sep 10, 2020'
#  'Sunday Sep 13, 2020' 'Monday Sep 14, 2020' 'Thursday Sep 17, 2020'
#  'Sunday Sep 20, 2020' 'Monday Sep 21, 2020' 'Thursday Sep 24, 2020'
#  'Sunday Sep 27, 2020' 'Monday Sep 28, 2020' 'Thursday Oct 1, 2020'
#  'Sunday Oct 4, 2020' 'Monday Oct 5, 2020' 'Thursday Oct 8, 2020'
#  'Sunday Oct 11, 2020' 'Monday Oct 12, 2020' 'Tuesday Oct 13, 2020'
#  'Sunday Oct 18, 2020' 'Monday Oct 19, 2020' 'Thursday Oct 22, 2020'
#  'Sunday Oct 25, 2020' 'Monday Oct 26, 2020' 'Thursday Oct 29, 2020'
#  'Sunday Nov 1, 2020' 'Monday Nov 2, 2020' 'Thursday Nov 5, 2020'
#  'Sunday Nov 8, 2020' 'Monday Nov 9, 2020' 'Thursday Nov 12, 2020'
#  'Sunday Nov 15, 2020' 'Monday Nov 16, 2020' 'Thursday Nov 19, 2020'
#  'Sunday Nov 22, 2020' 'Monday Nov 23, 2020' 'Thursday Nov 26, 2020'
#  'Sunday Nov 29, 2020' 'Monday Nov 30, 2020' 'Wednesday Dec 2, 2020'
#  'Sunday Dec 6, 2020' 'Monday Dec 7, 2020' 'Tuesday Dec 8, 2020'
#  'Thursday Dec 10, 2020' 'Sunday Dec 13, 2020' 'Monday Dec 14, 2020'
#  'Thursday Dec 17, 2020' 'Saturday Dec 19, 2020' 'Sunday Dec 20, 2020'
#  'Monday Dec 21, 2020' 'Friday Dec 25, 2020' 'Saturday Dec 26, 2020'
#  'Sunday Dec 27, 2020' 'Monday Dec 28, 2020' 'Sunday Jan 3, 2021'
#  'Saturday Jan 9, 2021' 'Sunday Jan 10, 2021' 'Saturday Jan 16, 2021'
#  'Sunday Jan 17, 2021' 'Sunday Jan 24, 2021' 'Sunday Feb 7, 2021']
# [ 61  58  50  48  44  33  42  31  25  14   9   6  17  69  66  67  56  60
#   53  52  39  32  49  41  23  29  28  12   5  21   7  78  73  46   2  63
#   40  24  22  19  16  10   8  72  68  45  34  36  30  37  59  38  15  13
#   26  18   4  51  11  79  71  20  77  75  64  70  43  65  62  54  81  57
#   27  55  35  80  74  47   3  83   1  95  89  82  84  76  94  88  85  86
#   92  97  87  90  91  93  96 100  98  99 108 102 103 109 105 101 111 104]
# ['Denver Broncos' 'Carolina Panthers' 'Baltimore Ravens' 'Buffalo Bills'
#  'Jacksonville Jaguars' 'Green Bay Packers' 'Atlanta Falcons'
#  'Tampa Bay Buccaneers' 'Houston Texans' 'Chicago Bears' 'New York Jets'
#  'Cincinnati Bengals' 'Philadelphia Eagles' 'Cleveland Browns'
#  'Kansas City Chiefs' 'San Diego Chargers' 'Tennessee Titans'
#  'Minnesota Vikings' 'New Orleans Saints' 'Oakland Raiders'
#  'Seattle Seahawks' 'Miami Dolphins' 'Indianapolis Colts' 'Detroit Lions'
#  'Dallas Cowboys' 'New York Giants' 'Arizona Cardinals'
#  'New England Patriots' 'Washington Redskins' 'Pittsburgh Steelers'
#  'San Francisco 49ers' 'Los Angeles Rams' 'Los Angeles Chargers'
#  'Las Vegas Raiders' 'Washington Football Team']
# ['Denver Broncos' 'Baltimore Ravens' 'Jacksonville Jaguars'
#  'Atlanta Falcons' 'Houston Texans' 'New York Jets' 'Philadelphia Eagles'
#  'Kansas City Chiefs' 'Tennessee Titans' 'New Orleans Saints'
#  'Seattle Seahawks' 'Indianapolis Colts' 'Dallas Cowboys'
#  'Arizona Cardinals' 'Washington Redskins' 'San Francisco 49ers'
#  'Buffalo Bills' 'Pittsburgh Steelers' 'Cleveland Browns' 'Detroit Lions'
#  'New England Patriots' 'Carolina Panthers' 'New York Giants'
#  'Los Angeles Rams' 'Oakland Raiders' 'San Diego Chargers'
#  'Minnesota Vikings' 'Chicago Bears' 'Cincinnati Bengals' 'Miami Dolphins'
#  'Green Bay Packers' 'Tampa Bay Buccaneers' 'Los Angeles Chargers'
#  'Washington Football Team' 'Las Vegas Raiders']
# ['Carolina Panthers' 'Buffalo Bills' 'Green Bay Packers'
#  'Tampa Bay Buccaneers' 'Chicago Bears' 'Cincinnati Bengals'
#  'Cleveland Browns' 'San Diego Chargers' 'Minnesota Vikings'
#  'Oakland Raiders' 'Miami Dolphins' 'Detroit Lions' 'New York Giants'
#  'New England Patriots' 'Pittsburgh Steelers' 'Los Angeles Rams'
#  'New York Jets' 'Baltimore Ravens' 'Tennessee Titans'
#  'Kansas City Chiefs' 'San Francisco 49ers' 'Dallas Cowboys'
#  'New Orleans Saints' 'Seattle Seahawks' 'Atlanta Falcons'
#  'Indianapolis Colts' 'Jacksonville Jaguars' 'Philadelphia Eagles'
#  'Houston Texans' 'Arizona Cardinals' 'Denver Broncos'
#  'Washington Redskins' 'Los Angeles Chargers' 'Las Vegas Raiders'
#  'Washington Football Team']
# [ True False]
# ['Sports Authority Field at Mile High' 'M&T Bank Stadium' 'EverBank Field'
#  'Georgia Dome' 'NRG Stadium' 'MetLife Stadium' 'Lincoln Financial Field'
#  'Arrowhead Stadium' 'Nissan Stadium' 'Mercedes-Benz Superdome'
#  'CenturyLink Field' 'Lucas Oil Stadium' 'AT&T Stadium'
#  'University of Phoenix Stadium' 'FedExField' "Levi's Stadium"
#  'New Era Field' 'Heinz Field' 'FirstEnergy Stadium' 'Ford Field'
#  'Gillette Stadium' 'Bank of America Stadium'
#  'Los Angeles Memorial Coliseum' 'Oakland-Alameda County Coliseum'
#  'Qualcomm Stadium' 'U.S. Bank Stadium' 'Soldier Field'
#  'Paul Brown Stadium' 'Hard Rock Stadium' 'Lambeau Field'
#  'Raymond James Stadium' 'Wembley Stadium' 'Twickenham Stadium'
#  'Azteca Stadium' 'StubHub Center' 'Mercedes-Benz Stadium'
#  'State Farm Stadium' 'TIAA Bank Stadium' 'Ring Central Coliseum'
#  'Empower Field at Mile High' 'Tottenham Stadium' 'Bills Stadium'
#  'SoFi Stadium' 'Lumen Field' 'Allegiant Stadium']
# ['85 degrees, relative humidity 12%, wind 10 mph, wind chill 0'
#  '84 degrees, relative humidity 44%, wind 8 mph, wind chill 0'
#  '90 degrees, relative humidity 55%, wind 3 mph, wind chill 0' nan
#  '79 degrees, relative humidity 40%, wind 17 mph, wind chill 0'
#  '85 degrees, relative humidity 42%, wind 14 mph, wind chill 0'
#  '74 degrees, relative humidity 51%, wind 9 mph, wind chill 0'
#  '76 degrees, relative humidity 47%, wind 5 mph'
#  '61 degrees, relative humidity 68%, wind 2 mph, wind chill 0'
#  '79 degrees, relative humidity 41%, wind 4 mph, wind chill 0'
#  '66 degrees, relative humidity 56%, wind 17 mph, wind chill 0'
#  '60 degrees, relative humidity 65%, wind 11 mph, wind chill 0'
#  '72 degrees, relative humidity 86%, wind 4 mph'
#  '74 degrees, relative humidity 70%, wind 7 mph, wind chill 0'
#  '79 degrees, relative humidity 66%, wind 10 mph, wind chill 0'
#  '82 degrees, relative humidity 60%, wind 4 mph, wind chill 0'
#  '81 degrees, relative humidity 65%, wind 6 mph, wind chill 0'
#  '80 degrees, relative humidity 74%, wind 5 mph, wind chill 0'
#  '88 degrees, relative humidity 39%, wind 3 mph, wind chill 0'
#  '79 degrees, relative humidity 41%, wind 7 mph, wind chill 0'
#  '85 degrees, relative humidity 15%, wind 4 mph, wind chill 0'
#  '82 degrees, relative humidity 51%, wind 7 mph, wind chill 0'
#  '84 degrees, relative humidity 36%, wind 5 mph, wind chill 0'
#  '68 degrees, relative humidity 60%, wind 4 mph, wind chill 0'
#  '64 degrees, relative humidity 44%, wind 8 mph, wind chill 0'
#  '80 degrees, relative humidity 63%, no wind, wind chill 0'
#  '81 degrees, relative humidity 53%, wind 3 mph, wind chill 0'
#  '86 degrees, relative humidity 65%, wind 16 mph, wind chill 0'
#  '72 degrees, relative humidity 84%, wind 17 mph, wind chill 0'
#  '88 degrees, relative humidity 0%, wind 8 mph, wind chill 0'
#  '67 degrees, relative humidity 37%, wind 2 mph, wind chill 0'
#  '89 degrees, relative humidity 49%, wind 2 mph'
#  '91 degrees, relative humidity 58%, wind 4 mph'
#  '66 degrees, relative humidity 63%, wind 6 mph, wind chill 0'
#  '73 degrees, relative humidity 39%, wind 7 mph, wind chill 0'
#  '65 degrees, relative humidity 63%, wind 9 mph, wind chill 0'
#  '62 degrees, relative humidity 77%, wind 2 mph, wind chill 0'
#  '59 degrees, relative humidity 59%, wind 7 mph, wind chill 0'
#  '62 degrees, relative humidity 84%, wind 6 mph, wind chill 0'
#  '56 degrees, relative humidity 91%, wind 7 mph, wind chill 0'
#  '65 degrees, relative humidity 84%, wind 2 mph, wind chill 0'
#  '61 degrees, relative humidity 77%, no wind, wind chill 0'
#  '67 degrees, relative humidity 89%, wind 1 mph, wind chill 0'
#  '88 degrees, relative humidity 63%, wind 7 mph'
#  '68 degrees, relative humidity 60%, wind 10 mph, wind chill 0'
#  '74 degrees, relative humidity 73%, wind 8 mph, wind chill 0'
#  '59 degrees, relative humidity 80%, wind 6 mph'
#  '75 degrees, relative humidity 34%, wind 16 mph, wind chill 0'
#  '58 degrees, relative humidity 58%, wind 13 mph, wind chill 0'
#  '88 degrees, relative humidity 53%, wind 15 mph, wind chill 0'
#  '57 degrees, relative humidity 60%, wind 9 mph'
#  '62 degrees, relative humidity 53%, wind 16 mph, wind chill 0'
#  '72 degrees, relative humidity 18%, wind 5 mph, wind chill 0'
#  '91 degrees, relative humidity 18%, wind 5 mph, wind chill 0'
#  '75 degrees, relative humidity 39%, wind 7 mph, wind chill 0'
#  '49 degrees, relative humidity 0%, wind 7 mph'
#  '66 degrees, relative humidity 35%, wind 7 mph, wind chill 0'
#  '70 degrees, relative humidity 63%, wind 9 mph, wind chill 0'
#  '72 degrees, relative humidity 61%, wind 22 mph, wind chill 0'
#  '69 degrees, relative humidity 93%, wind 7 mph, wind chill 0'
#  '66 degrees, relative humidity 54%, wind 14 mph, wind chill 0'
#  '75 degrees, relative humidity 70%, wind 10 mph, wind chill 0'
#  '81 degrees, relative humidity 79%, wind 15 mph, wind chill 0'
#  '66 degrees, relative humidity 65%, wind 6 mph, wind chill 0'
#  '69 degrees, relative humidity 62%, wind 13 mph, wind chill 0'
#  '61 degrees, relative humidity 100%, wind 6 mph, wind chill 0'
#  '69 degrees, relative humidity 63%, wind 8 mph, wind chill 0'
#  '54 degrees, relative humidity 83%, wind 10 mph, wind chill 0'
#  '47 degrees, relative humidity 63%, wind 10 mph'
#  '55 degrees, relative humidity 61%, wind 12 mph, wind chill 0'
#  '70 degrees, relative humidity 47%, wind 6 mph, wind chill 0'
#  '62 degrees, relative humidity 46%, wind 20 mph, wind chill 0'
#  '81 degrees, relative humidity 48%, wind 11 mph, wind chill 0'
#  '65 degrees, relative humidity 50%, wind 5 mph, wind chill 0'
#  '68 degrees, relative humidity 50%, wind 5 mph'
#  '68 degrees, relative humidity 47%, wind 9 mph, wind chill 0'
#  '68 degrees, relative humidity 49%, wind 5 mph, wind chill 0'
#  '63 degrees, relative humidity 54%, wind 13 mph'
#  '71 degrees, relative humidity 17%, wind 5 mph, wind chill 0'
#  '71 degrees, relative humidity 78%, wind 3 mph, wind chill 0'
#  '54 degrees, relative humidity 90%, wind 2 mph, wind chill 0'
#  '85 degrees, relative humidity 53%, wind 5 mph, wind chill 0'
#  '49 degrees, relative humidity 92%, wind 9 mph'
#  '53 degrees, relative humidity 91%, wind 15 mph'
#  '86 degrees, relative humidity 54%, wind 15 mph'
#  '76 degrees, relative humidity 19%, wind 6 mph, wind chill 0'
#  '58 degrees, relative humidity 71%, wind 12 mph, wind chill 0'
#  '76 degrees, wind 2 mph' '62 degrees, wind 7 mph'
#  '80 degrees, wind 14 mph' '56 degrees, wind 9 mph'
#  '65 degrees, wind 15 mph' '58 degrees, wind 4 mph'
#  '75 degrees, wind 2 mph' '70 degrees, no wind' '68 degrees, wind 7 mph'
#  '76 degrees, wind 6 mph' '65 degrees, wind 6 mph'
#  '61 degrees, wind 4 mph' '54 degrees, wind 3 mph'
#  '45 degrees, wind 6 mph' '81 degrees, wind 4 mph'
#  '56 degrees, wind 3 mph' '69 degrees, wind 10 mph'
#  '58 degrees, wind 7 mph' '58 degrees, wind 10 mph'
#  '85 degrees, wind 11 mph' '56 degrees, wind 7 mph'
#  '43 degrees, wind 3 mph' '56 degrees, wind 2 mph'
#  '63 degrees, wind 6 mph' '36 degrees, wind 8 mph'
#  '41 degrees, wind 10 mph' '46 degrees, wind 9 mph'
#  '36 degrees, wind 27 mph' '63 degrees, wind 3 mph'
#  '64 degrees, wind 6 mph' '54 degrees, wind 5 mph'
#  '38 degrees, wind 23 mph' '42 degrees, wind 13 mph'
#  '40 degrees, wind 11 mph' '50 degrees, wind 12 mph'
#  '79 degrees, wind 13 mph' '48 degrees, wind 10 mph'
#  '81 degrees, wind 6 mph' '59 degrees, wind 12 mph'
#  '47 degrees, wind 10 mph' '44 degrees, wind 21 mph'
#  '47 degrees, wind 7 mph' '33 degrees, wind 5 mph'
#  '42 degrees, wind 10 mph' '70 degrees, wind 10 mph'
#  '32 degrees, wind 8 mph' '47 degrees, wind 3 mph'
#  '39 degrees, wind 8 mph' '59 degrees, wind 4 mph'
#  '43 degrees, wind 7 mph' '72 degrees, wind 7 mph'
#  '37 degrees, wind 4 mph' '21 degrees, wind 7 mph'
#  '27 degrees, wind 9 mph' '37 degrees, wind 6 mph'
#  '28 degrees, wind 15 mph' '77 degrees, wind 18 mph'
#  '50 degrees, wind 5 mph' '71 degrees, wind 5 mph'
#  '35 degrees, wind 3 mph' '54 degrees, wind 8 mph'
#  '65 degrees, wind 1 mph' '26 degrees, wind 5 mph'
#  '79 degrees, wind 9 mph' '32 degrees, no wind' '31 degrees, wind 3 mph'
#  '36 degrees, wind 5 mph' '35 degrees, wind 5 mph'
#  '26 degrees, wind 15 mph' '11 degrees, wind 12 mph'
#  '24 degrees, wind 8 mph' '55 degrees, wind 1 mph' '1 degrees, wind 5 mph'
#  '62 degrees, wind 9 mph' '18 degrees, wind 9 mph'
#  '62 degrees, wind 5 mph' '40 degrees, wind 10 mph'
#  '56 degrees, wind 5 mph' '38 degrees, wind 13 mph'
#  '37 degrees, wind 1 mph' '37 degrees, wind 8 mph'
#  '67 degrees, wind 5 mph' '40 degrees, wind 6 mph'
#  '50 degrees, wind 9 mph' '39 degrees, wind 2 mph'
#  '59 degrees, wind 6 mph' '41 degrees, wind 9 mph'
#  '53 degrees, wind 9 mph' '42 degrees, wind 11 mph'
#  '41 degrees, wind 1 mph' '50 degrees, wind 10 mph'
#  '52 degrees, wind 7 mph' '80 degrees, wind 15 mph' '59 degrees, no wind'
#  '45 degrees, wind 9 mph' '59 degrees, wind 10 mph'
#  '53 degrees, wind 1 mph' '38 degrees, wind 7 mph'
#  '17 degrees, wind 16 mph' '14 degrees, wind 7 mph'
#  '28 degrees, wind 6 mph' '33 degrees, wind 9 mph'
#  '63 degrees, wind 8 mph' '64 degrees, wind 10 mph'
#  '68 degrees, wind 9 mph' '63 degrees, wind 11 mph'
#  '90 degrees, wind 2 mph' '87 degrees, wind 8 mph'
#  '71 degrees, wind 11 mph' '73 degrees, wind 12 mph'
#  '69 degrees, wind 2 mph' '83 degrees, wind 5 mph'
#  '88 degrees, wind 7 mph' '80 degrees, wind 2 mph'
#  '84 degrees, wind 10 mph' '78 degrees, wind 1 mph'
#  '71 degrees, wind 7 mph' '70 degrees, wind 6 mph'
#  '72 degrees, wind 5 mph' '74 degrees, wind 3 mph'
#  '65 degrees, wind 12 mph' '68 degrees, wind 13 mph'
#  '88 degrees, wind 5 mph' '82 degrees, wind 6 mph'
#  '89 degrees, wind 5 mph' '84 degrees, wind 4 mph'
#  '89 degrees, wind 6 mph' '88 degrees, wind 4 mph'
#  '89 degrees, wind 8 mph' '84 degrees, wind 5 mph' '76 degrees, no wind'
#  '65 degrees, wind 5 mph' '63 degrees, wind 13 mph'
#  '61 degrees, wind 6 mph' '64 degrees, wind 5 mph'
#  '91 degrees, wind 8 mph' '72 degrees, wind 6 mph'
#  '61 degrees, wind 8 mph' '82 degrees, wind 14 mph'
#  '76 degrees, wind 9 mph' '89 degrees, wind 9 mph'
#  '63 degrees, wind 10 mph' '67 degrees, wind 8 mph'
#  '77 degrees, wind 10 mph' '73 degrees, wind 9 mph'
#  '76 degrees, wind 7 mph' '72 degrees, wind 8 mph' '78 degrees, no wind'
#  '69 degrees, wind 7 mph' '73 degrees, wind 13 mph'
#  '68 degrees, wind 4 mph' '88 degrees, wind 10 mph'
#  '60 degrees, wind 14 mph' '57 degrees, wind 7 mph'
#  '62 degrees, wind 1 mph' '74 degrees, wind 9 mph'
#  '86 degrees, wind 18 mph' '70 degrees, wind 15 mph'
#  '74 degrees, wind 12 mph' '54 degrees, wind 10 mph'
#  '52 degrees, wind 10 mph' '68 degrees, wind 10 mph'
#  '79 degrees, wind 6 mph' '90 degrees, wind 4 mph'
#  '75 degrees, wind 7 mph' '70 degrees, wind 9 mph'
#  '56 degrees, wind 11 mph' '63 degrees, wind 5 mph'
#  '42 degrees, wind 7 mph' '39 degrees, wind 9 mph'
#  '62 degrees, wind 8 mph' '67 degrees, wind 12 mph'
#  '50 degrees, wind 2 mph' '60 degrees, wind 4 mph'
#  '44 degrees, wind 12 mph' '68 degrees, wind 11 mph'
#  '78 degrees, wind 12 mph' '61 degrees, wind 5 mph'
#  '56 degrees, wind 6 mph' '75 degrees, wind 10 mph'
#  '36 degrees, wind 11 mph' '77 degrees, wind 2 mph'
#  '42 degrees, wind 2 mph' '53 degrees, wind 4 mph'
#  '76 degrees, wind 5 mph' '44 degrees, wind 4 mph'
#  '79 degrees, wind 16 mph' '68 degrees, no wind' '68 degrees, wind 5 mph'
#  '48 degrees, wind 5 mph' '49 degrees, wind 6 mph'
#  '40 degrees, wind 17 mph' '33 degrees, wind 16 mph'
#  '38 degrees, wind 16 mph' '28 degrees, wind 14 mph'
#  '50 degrees, wind 23 mph' '81 degrees, wind 9 mph'
#  '60 degrees, wind 7 mph' '66 degrees, no wind' '33 degrees, no wind'
#  '47 degrees, wind 23 mph' '49 degrees, wind 17 mph'
#  '46 degrees, wind 3 mph' '47 degrees, wind 17 mph'
#  '66 degrees, wind 12 mph' '61 degrees, wind 13 mph'
#  '72 degrees, wind 1 mph' '50 degrees, wind 1 mph'
#  '48 degrees, wind 13 mph' '54 degrees, wind 6 mph'
#  '70 degrees, wind 7 mph' '80 degrees, wind 11 mph'
#  '42 degrees, wind 8 mph' '48 degrees, no wind' '58 degrees, wind 11 mph'
#  '44 degrees, wind 3 mph' '61 degrees, wind 9 mph'
#  '32 degrees, wind 15 mph' '41 degrees, wind 5 mph'
#  '31 degrees, wind 11 mph' '29 degrees, wind 24 mph'
#  '39 degrees, wind 11 mph' '55 degrees, wind 9 mph'
#  '46 degrees, wind 13 mph' '60 degrees, wind 3 mph' '83 degrees, no wind'
#  '33 degrees, wind 12 mph' '55 degrees, wind 7 mph'
#  '22 degrees, wind 8 mph' '51 degrees, wind 5 mph' '36 degrees, no wind'
#  '35 degrees, no wind' '47 degrees, wind 15 mph' '42 degrees, wind 4 mph'
#  '65 degrees, wind 17 mph' '57 degrees, wind 4 mph'
#  '71 degrees, wind 2 mph' '63 degrees, wind 14 mph'
#  '10 degrees, wind 6 mph' '35 degrees, wind 7 mph'
#  '55 degrees, wind 6 mph' '35 degrees, wind 2 mph'
#  '23 degrees, wind 15 mph' '52 degrees, no wind' '29 degrees, wind 15 mph'
#  '11 degrees, wind 3 mph' '19 degrees, wind 17 mph'
#  '13 degrees, wind 14 mph' '16 degrees, wind 16 mph'
#  '71 degrees, wind 9 mph' '19 degrees, wind 12 mph'
#  '40 degrees, wind 7 mph' '17 degrees, wind 4 mph'
#  '23 degrees, wind 5 mph' '71 degrees, wind 3 mph'
#  '62 degrees, wind 2 mph' '67 degrees, wind 3 mph'
#  '33 degrees, wind 10 mph' '62 degrees, wind 3 mph'
#  '53 degrees, wind 18 mph' '32 degrees, wind 16 mph'
#  '24 degrees, wind 12 mph' '18 degrees, wind 2 mph'
#  '48 degrees, wind 3 mph' '47 degrees, wind 5 mph'
#  '81 degrees, wind 8 mph' '61 degrees, wind 12 mph'
#  '62 degrees, wind 10 mph' '59 degrees, wind 7 mph'
#  '89 degrees, wind 7 mph' '84 degrees, wind 8 mph'
#  '82 degrees, wind 3 mph' '83 degrees, wind 6 mph'
#  '80 degrees, wind 5 mph' '81 degrees, wind 12 mph'
#  '80 degrees, wind 10 mph' '80 degrees, wind 4 mph'
#  '91 degrees, wind 9 mph' '86 degrees, wind 2 mph'
#  '92 degrees, wind 4 mph' '97 degrees, wind 15 mph'
#  '79 degrees, wind 2 mph' '83 degrees, wind 11 mph'
#  '80 degrees, wind 3 mph' '62 degrees, wind 6 mph'
#  '89 degrees, wind 10 mph' '70 degrees, wind 4 mph'
#  '90 degrees, wind 7 mph' '77 degrees, wind 5 mph'
#  '75 degrees, wind 3 mph' '49 degrees, wind 9 mph'
#  '66 degrees, wind 5 mph' '86 degrees, wind 10 mph'
#  '71 degrees, wind 8 mph' '78 degrees, wind 9 mph'
#  '66 degrees, wind 6 mph' '87 degrees, wind 4 mph'
#  '77 degrees, wind 7 mph' '58 degrees, wind 5 mph'
#  '79 degrees, wind 15 mph' '53 degrees, wind 5 mph'
#  '70 degrees, wind 3 mph' '51 degrees, wind 6 mph'
#  '51 degrees, wind 9 mph' '25 degrees, wind 6 mph'
#  '66 degrees, wind 4 mph' '45 degrees, no wind' '37 degrees, wind 5 mph'
#  '49 degrees, wind 19 mph' '44 degrees, wind 9 mph'
#  '79 degrees, wind 7 mph' '68 degrees, wind 15 mph'
#  '46 degrees, wind 16 mph' '54 degrees, wind 15 mph'
#  '52 degrees, wind 12 mph' '48 degrees, wind 12 mph'
#  '61 degrees, wind 10 mph' '48 degrees, wind 18 mph'
#  '47 degrees, wind 11 mph' '56 degrees, wind 12 mph'
#  '51 degrees, wind 11 mph' '69 degrees, wind 8 mph'
#  '82 degrees, wind 1 mph' '82 degrees, wind 8 mph'
#  '55 degrees, wind 5 mph' '49 degrees, wind 12 mph'
#  '53 degrees, wind 16 mph' '87 degrees, wind 16 mph'
#  '56 degrees, wind 4 mph' '53 degrees, wind 3 mph'
#  '40 degrees, wind 2 mph' '40 degrees, wind 4 mph'
#  '36 degrees, wind 9 mph' '37 degrees, wind 12 mph'
#  '39 degrees, wind 6 mph' '43 degrees, wind 5 mph'
#  '46 degrees, wind 10 mph' '46 degrees, wind 4 mph'
#  '69 degrees, wind 16 mph' '33 degrees, wind 6 mph'
#  '75 degrees, wind 1 mph' '38 degrees, wind 5 mph' '62 degrees, no wind'
#  '48 degrees, wind 8 mph' '48 degrees, wind 6 mph'
#  '73 degrees, wind 8 mph' '42 degrees, wind 1 mph'
#  '69 degrees, wind 4 mph' '65 degrees, no wind' '57 degrees, wind 1 mph'
#  '56 degrees, wind 10 mph' '41 degrees, wind 7 mph'
#  '86 degrees, wind 15 mph' '81 degrees, wind 15 mph'
#  '52 degrees, wind 3 mph' '63 degrees, wind 12 mph'
#  '78 degrees, wind 13 mph' '34 degrees, wind 20 mph'
#  '57 degrees, wind 6 mph' '70 degrees, wind 13 mph'
#  '53 degrees, wind 6 mph' '45 degrees, wind 2 mph'
#  '57 degrees, wind 8 mph' '36 degrees, wind 15 mph'
#  '44 degrees, wind 5 mph' '25 degrees, wind 10 mph'
#  '31 degrees, wind 12 mph' '28 degrees, wind 4 mph' '27 degrees, no wind'
#  '82 degrees, wind 13 mph' '55 degrees, wind 8 mph'
#  '29 degrees, wind 4 mph' '48 degrees, wind 9 mph'
#  '39 degrees, wind 5 mph' '51 degrees, wind 8 mph' '46 degrees, no wind'
#  '39 degrees, wind 7 mph' '45 degrees, wind 10 mph'
#  '43 degrees, wind 2 mph' '64 degrees, wind 12 mph'
#  '43 degrees, wind 10 mph' '61 degrees, wind 11 mph'
#  '42 degrees, wind 5 mph' '60 degrees, wind 5 mph'
#  '40 degrees, wind 12 mph' '37 degrees, wind 9 mph'
#  '43 degrees, wind 8 mph' '58 degrees, wind 14 mph'
#  '37 degrees, wind 2 mph' '33 degrees, wind 2 mph'
#  '42 degrees, wind 9 mph' '48 degrees, wind 2 mph'
#  '45 degrees, wind 5 mph' '45 degrees, wind 15 mph'
#  '65 degrees, wind 3 mph' '39 degrees, wind 12 mph'
#  '32 degrees, wind 13 mph' '26 degrees, wind 3 mph'
#  '19 degrees, wind 14 mph'
#  '65 degrees, relative humidity 69%, wind 10 mph'
#  '77 degrees, relative humidity 46%, wind 6 mph'
#  '87 degrees, relative humidity 53%, wind 3 mph'
#  '71 degrees, relative humidity 55%, wind 10 mph'
#  '91 degrees, relative humidity 54%, wind 6 mph'
#  '91 degrees, relative humidity 56%, wind 8 mph'
#  '79 degrees, relative humidity 49%, wind 4 mph'
#  '64 degrees, relative humidity 82%, wind 7 mph'
#  '77 degrees, relative humidity 52%, wind 10 mph'
#  '93 degrees, relative humidity 52%, wind 9 mph'
#  '66 degrees, relative humidity 62%, wind 2 mph'
#  '68 degrees, relative humidity 66%, wind 15 mph'
#  '85 degrees, relative humidity 55%, wind 3 mph'
#  '79 degrees, relative humidity 48%, wind 5 mph'
#  '81 degrees, relative humidity 45%, wind 5 mph'
#  '93 degrees, relative humidity 45%, wind 1 mph'
#  '82 degrees, relative humidity 60%, wind 8 mph'
#  '80 degrees, relative humidity 46%, wind 7 mph'
#  '72 degrees, relative humidity 75%, wind 5 mph'
#  '87 degrees, relative humidity 67%, wind 4 mph'
#  '81 degrees, relative humidity 51%, wind 3 mph'
#  '70 degrees, relative humidity 61%, wind 13 mph'
#  '87 degrees, relative humidity 14%, wind 3 mph'
#  '85 degrees, relative humidity 44%, wind 4 mph'
#  '72 degrees, relative humidity 69%, wind 3 mph'
#  '73 degrees, relative humidity 87%, wind 9 mph'
#  '83 degrees, relative humidity 53%, wind 13 mph'
#  '69 degrees, relative humidity 93%, wind 7 mph'
#  '84 degrees, relative humidity 53%, wind 7 mph'
#  '81 degrees, relative humidity 49%, wind 10 mph'
#  '88 degrees, relative humidity 46%, wind 11 mph'
#  '87 degrees, relative humidity 37%, wind 4 mph'
#  '63 degrees, relative humidity 85%, wind 8 mph'
#  '79 degrees, relative humidity 36%, wind 3 mph'
#  '83 degrees, relative humidity 33%, wind 12 mph'
#  '87 degrees, relative humidity 39%, wind 5 mph'
#  '60 degrees, relative humidity 62%, wind 3 mph'
#  '58 degrees, relative humidity 71%, wind 10 mph'
#  '83 degrees, relative humidity 57%, wind 8 mph'
#  '88 degrees, relative humidity 53%, wind 15 mph'
#  '77 degrees, relative humidity 42%, wind 11 mph'
#  '74 degrees, relative humidity 41%, wind 2 mph'
#  '67 degrees, relative humidity 89%, wind 8 mph'
#  '87 degrees, relative humidity 11%, wind 14 mph'
#  '76 degrees, relative humidity 72%, wind 1 mph'
#  '57 degrees, relative humidity 56%, wind 7 mph'
#  '68 degrees, relative humidity 68%, wind 10 mph'
#  '77 degrees, relative humidity 71%, wind 13 mph'
#  '72 degrees, relative humidity 59%, wind 4 mph'
#  '59 degrees, relative humidity 60%, wind 15 mph'
#  '76 degrees, relative humidity 68%, wind 6 mph'
#  '66 degrees, relative humidity 73%, wind 10 mph'
#  '70 degrees, relative humidity 66%, wind 8 mph'
#  '70 degrees, relative humidity 74%, wind 7 mph'
#  '85 degrees, relative humidity 35%, wind 12 mph'
#  '59 degrees, relative humidity 75%, wind 3 mph'
#  '87 degrees, relative humidity 36%, wind 8 mph'
#  '54 degrees, relative humidity 61%, wind 13 mph'
#  '61 degrees, relative humidity 86%, wind 14 mph'
#  '84 degrees, relative humidity 66%, wind 13 mph'
#  '64 degrees, relative humidity 43%, wind 7 mph'
#  '58 degrees, relative humidity 38%, wind 20 mph'
#  '56 degrees, relative humidity 47%, wind 2 mph'
#  '81 degrees, relative humidity 56%, wind 3 mph'
#  '77 degrees, relative humidity 42%, wind 2 mph'
#  '66 degrees, relative humidity 38%, wind 7 mph'
#  '69 degrees, relative humidity 9%, wind 7 mph'
#  '71 degrees, relative humidity 61%, wind 9 mph'
#  '43 degrees, relative humidity 73%, wind 5 mph'
#  '75 degrees, relative humidity 7%, wind 6 mph'
#  '65 degrees, relative humidity 54%, wind 7 mph'
#  '55 degrees, relative humidity 93%, wind 12 mph'
#  '70 degrees, relative humidity 63%, wind 2 mph'
#  '56 degrees, relative humidity 78%, wind 3 mph'
#  '55 degrees, relative humidity 74%, wind 6 mph'
#  '77 degrees, relative humidity 40%, wind 2 mph'
#  '54 degrees, relative humidity 84%, wind 6 mph'
#  '50 degrees, relative humidity 79%, wind 8 mph'
#  '58 degrees, relative humidity 73%, no wind'
#  '54 degrees, relative humidity 87%, wind 23 mph'
#  '52 degrees, relative humidity 59%, wind 9 mph'
#  '48 degrees, relative humidity 69%, wind 5 mph'
#  '59 degrees, relative humidity 67%, wind 3 mph'
#  '66 degrees, relative humidity 20%, wind 19 mph'
#  '49 degrees, relative humidity 91%, wind 11 mph'
#  '54 degrees, relative humidity 60%, wind 5 mph'
#  '59 degrees, relative humidity 50%, wind 2 mph'
#  '53 degrees, relative humidity 54%, wind 6 mph'
#  '42 degrees, relative humidity 56%, wind 18 mph'
#  '58 degrees, relative humidity 34%, wind 5 mph'
#  '52 degrees, relative humidity 37%, wind 13 mph'
#  '48 degrees, relative humidity 47%, wind 12 mph'
#  '85 degrees, relative humidity 64%, wind 11 mph'
#  '54 degrees, relative humidity 37%, wind 15 mph'
#  '71 degrees, relative humidity 34%, wind 6 mph'
#  '54 degrees, relative humidity 66%, wind 6 mph'
#  '55 degrees, relative humidity 32%, wind 4 mph'
#  '48 degrees, relative humidity 41%, wind 1 mph'
#  '51 degrees, relative humidity 58%, wind 10 mph'
#  '54 degrees, relative humidity 84%, wind 9 mph'
#  '40 degrees, relative humidity 80%, wind 12 mph'
#  '56 degrees, relative humidity 53%, wind 9 mph'
#  '77 degrees, relative humidity 53%, wind 8 mph'
#  '63 degrees, relative humidity 35%, wind 9 mph'
#  '48 degrees, relative humidity 50%, wind 8 mph'
#  '55 degrees, relative humidity 44%, wind 12 mph'
#  '77 degrees, relative humidity 32%, wind 3 mph'
#  '36 degrees, relative humidity 57%, wind 10 mph'
#  '51 degrees, relative humidity 50%, wind 11 mph'
#  '62 degrees, relative humidity 74%, wind 13 mph'
#  '44 degrees, relative humidity 56%, wind 10 mph'
#  '55 degrees, relative humidity 79%, wind 4 mph'
#  '43 degrees, relative humidity 58%, wind 8 mph'
#  '72 degrees, relative humidity 46%, no wind'
#  '76 degrees, relative humidity 41%, wind 13 mph'
#  '42 degrees, relative humidity 57%, wind 13 mph'
#  '79 degrees, relative humidity 20%, no wind'
#  '67 degrees, relative humidity 63%, wind 7 mph'
#  '40 degrees, relative humidity 75%, wind 17 mph'
#  '48 degrees, relative humidity 59%, wind 12 mph'
#  '46 degrees, relative humidity 62%, wind 10 mph'
#  '39 degrees, relative humidity 73%, wind 14 mph'
#  '46 degrees, relative humidity 56%, wind 17 mph'
#  '43 degrees, relative humidity 93%, wind 12 mph'
#  '40 degrees, relative humidity 78%, wind 17 mph'
#  '52 degrees, relative humidity 54%, wind 9 mph'
#  '38 degrees, relative humidity 90%, wind 16 mph'
#  '63 degrees, relative humidity 40%, wind 7 mph'
#  '62 degrees, relative humidity 64%, wind 5 mph'
#  '64 degrees, relative humidity 77%, wind 16 mph'
#  '46 degrees, relative humidity 77%, wind 15 mph'
#  '46 degrees, relative humidity 91%, wind 6 mph'
#  '32 degrees, relative humidity 86%, wind 10 mph'
#  '40 degrees, relative humidity 91%, wind 13 mph'
#  '33 degrees, relative humidity 51%, wind 7 mph'
#  '36 degrees, relative humidity 55%, wind 20 mph'
#  '51 degrees, relative humidity 65%, wind 1 mph'
#  '44 degrees, relative humidity 66%, wind 9 mph'
#  '43 degrees, relative humidity 48%, wind 18 mph'
#  '48 degrees, relative humidity 58%, wind 16 mph'
#  '78 degrees, relative humidity 58%, wind 9 mph'
#  '37 degrees, relative humidity 75%, wind 10 mph'
#  '41 degrees, relative humidity 47%, wind 9 mph'
#  '32 degrees, relative humidity 56%, wind 8 mph'
#  '59 degrees, relative humidity 78%, wind 5 mph'
#  '60 degrees, relative humidity 79%, wind 4 mph'
#  '53 degrees, relative humidity 87%, wind 11 mph'
#  '33 degrees, relative humidity 55%, wind 3 mph'
#  '56 degrees, relative humidity 45%, wind 5 mph'
#  '11 degrees, relative humidity 70%, wind 7 mph'
#  '36 degrees, relative humidity 58%, wind 6 mph'
#  '24 degrees, relative humidity 88%, wind 8 mph'
#  '45 degrees, relative humidity 71%, wind 4 mph'
#  '48 degrees, relative humidity 42%, wind 19 mph'
#  '52 degrees, relative humidity 44%, wind 13 mph'
#  '59 degrees, relative humidity 52%, wind 7 mph'
#  '64 degrees, relative humidity 28%, wind 14 mph'
#  '55 degrees, relative humidity 58%, wind 6 mph'
#  '31 degrees, relative humidity 67%, wind 6 mph'
#  '73 degrees, relative humidity 65%, wind 11 mph'
#  '33 degrees, relative humidity 64%, wind 2 mph'
#  '58 degrees, relative humidity 66%, wind 12 mph'
#  '76 degrees, relative humidity 68%, wind 15 mph'
#  '49 degrees, relative humidity 41%, wind 10 mph'
#  '50 degrees, relative humidity 59%, wind 4 mph'
#  '44 degrees, relative humidity 52%, wind 6 mph'
#  '45 degrees, relative humidity 52%, wind 6 mph'
#  '67 degrees, relative humidity 8%, wind 3 mph'
#  '64 degrees, relative humidity 60%, wind 10 mph'
#  '43 degrees, relative humidity 87%, wind 7 mph'
#  '47 degrees, relative humidity 46%, wind 7 mph'
#  '45 degrees, relative humidity 66%, wind 10 mph'
#  '78 degrees, relative humidity 77%, wind 12 mph'
#  '43 degrees, relative humidity 85%, wind 7 mph'
#  '63 degrees, relative humidity 89%, wind 9 mph'
#  '64 degrees, relative humidity 80%, wind 7 mph'
#  '40 degrees, relative humidity 70%, wind 16 mph'
#  '43 degrees, relative humidity 41%, wind 2 mph'
#  '62 degrees, relative humidity 47%, no wind'
#  '31 degrees, relative humidity 43%, wind 6 mph'
#  '42 degrees, relative humidity 69%, wind 5 mph'
#  '46 degrees, relative humidity 91%, wind 7 mph'
#  '51 degrees, relative humidity 70%, wind 3 mph'
#  '44 degrees, relative humidity 88%, wind 4 mph'
#  '41 degrees, relative humidity 40%, wind 17 mph'
#  '56 degrees, relative humidity 67%, wind 11 mph'
#  '69 degrees, relative humidity 70%, wind 12 mph'
#  '23 degrees, relative humidity 74%, wind 8 mph'
#  '58 degrees, relative humidity 56%, wind 5 mph'
#  '56 degrees, relative humidity 95%, wind 7 mph'
#  '67 degrees, relative humidity 93%, wind 15 mph'
#  '81 degrees, relative humidity 59%, wind 5 mph'
#  '76 degrees, relative humidity 72%, wind 5 mph'
#  '80 degrees, relative humidity 85%, wind 3 mph'
#  '70 degrees, relative humidity 62%, wind 8 mph'
#  '76 degrees, relative humidity 68%, wind 5 mph'
#  '83 degrees, relative humidity 56%, wind 6 mph'
#  '66 degrees, relative humidity 68%, wind 6 mph'
#  '71 degrees, relative humidity 44%, wind 5 mph'
#  '79 degrees, relative humidity 14%, wind 10 mph'
#  '65 degrees, relative humidity 52%, wind 8 mph'
#  '90 degrees, relative humidity 68%, wind 5 mph'
#  '85 degrees, relative humidity 72%, wind 17 mph'
#  '66 degrees, relative humidity 41%, wind 12 mph'
#  '64 degrees, relative humidity 39%, wind 5 mph'
#  '72 degrees, relative humidity 60%, wind 5 mph'
#  '61 degrees, relative humidity 29%, wind 7 mph'
#  '62 degrees, relative humidity 34%, wind 12 mph'
#  '70 degrees, relative humidity 57%, wind 5 mph'
#  '81 degrees, relative humidity 75%, wind 12 mph'
#  '79 degrees, relative humidity 52%, wind 16 mph'
#  '76 degrees, relative humidity 82%, wind 5 mph'
#  '73 degrees, relative humidity 64%, wind 18 mph'
#  '79 degrees, relative humidity 69%, wind 6 mph'
#  '73 degrees, relative humidity 81%, wind 8 mph'
#  '75 degrees, relative humidity 72%, wind 2 mph'
#  '63 degrees, relative humidity 65%, wind 3 mph'
#  '55 degrees, relative humidity 39%, wind 7 mph'
#  '73 degrees, relative humidity 84%, wind 8 mph'
#  '64 degrees, relative humidity 55%, wind 6 mph'
#  '68 degrees, relative humidity 48%, wind 8 mph'
#  '52 degrees, relative humidity 54%, wind 10 mph'
#  '64 degrees, relative humidity 58%, wind 6 mph'
#  '86 degrees, relative humidity 71%, wind 13 mph'
#  '65 degrees, relative humidity 45%, wind 5 mph'
#  '75 degrees, relative humidity 87%, wind 6 mph'
#  '84 degrees, relative humidity 30%, wind 12 mph'
#  '73 degrees, relative humidity 39%, wind 14 mph'
#  '53 degrees, relative humidity 46%, wind 9 mph'
#  '57 degrees, relative humidity 74%, wind 7 mph'
#  '69 degrees, relative humidity 92%, wind 3 mph'
#  '64 degrees, relative humidity 57%, wind 8 mph'
#  '80 degrees, relative humidity 57%, wind 16 mph'
#  '70 degrees, relative humidity 89%, wind 4 mph'
#  '69 degrees, relative humidity 82%, wind 2 mph'
#  '73 degrees, relative humidity 41%, wind 6 mph'
#  '64 degrees, relative humidity 67%, wind 16 mph'
#  '54 degrees, relative humidity 90%, wind 10 mph'
#  '73 degrees, relative humidity 32%, wind 3 mph'
#  '58 degrees, relative humidity 45%, wind 7 mph'
#  '78 degrees, relative humidity 78%, wind 10 mph'
#  '63 degrees, relative humidity 44%, wind 6 mph'
#  '61 degrees, relative humidity 43%, wind 9 mph'
#  '61 degrees, relative humidity 58%, wind 10 mph'
#  '62 degrees, relative humidity 48%, no wind'
#  '61 degrees, relative humidity 52%, wind 7 mph'
#  '85 degrees, relative humidity 66%, wind 15 mph'
#  '88 degrees, relative humidity 48%, wind 12 mph'
#  '86 degrees, relative humidity 22%, wind 10 mph'
#  '51 degrees, relative humidity 92%, wind 6 mph'
#  '70 degrees, relative humidity 75%, wind 4 mph'
#  '55 degrees, relative humidity 88%, wind 3 mph'
#  '52 degrees, relative humidity 52%, wind 8 mph'
#  '48 degrees, relative humidity 77%, wind 8 mph'
#  '46 degrees, relative humidity 90%, wind 5 mph'
#  '14 degrees, relative humidity 78%, wind 11 mph'
#  '49 degrees, relative humidity 60%, wind 7 mph'
#  '76 degrees, relative humidity 76%, wind 8 mph'
#  '34 degrees, relative humidity 50%, wind 23 mph'
#  '86 degrees, relative humidity 73%, wind 10 mph'
#  '52 degrees, relative humidity 97%, wind 7 mph'
#  '41 degrees, relative humidity 87%, wind 17 mph'
#  '48 degrees, relative humidity 52%, wind 24 mph'
#  '49 degrees, relative humidity 56%, wind 35 mph'
#  '52 degrees, relative humidity 0%, wind 11 mph'
#  '64 degrees, relative humidity 23%, wind 10 mph'
#  '55 degrees, relative humidity 58%, wind 4 mph'
#  '40 degrees, relative humidity 41%, wind 20 mph'
#  '49 degrees, relative humidity 66%, wind 17 mph'
#  '39 degrees, relative humidity 46%, wind 8 mph'
#  '78 degrees, relative humidity 83%, wind 5 mph'
#  '79 degrees, relative humidity 71%, wind 14 mph'
#  '69 degrees, relative humidity 41%, wind 4 mph'
#  '71 degrees, relative humidity 63%, wind 19 mph'
#  '77 degrees, relative humidity 55%, wind 14 mph'
#  '75 degrees, relative humidity 49%, wind 1 mph'
#  '77 degrees, relative humidity 76%, wind 17 mph'
#  '61 degrees, relative humidity 72%, wind 2 mph'
#  '56 degrees, relative humidity 46%, wind 6 mph'
#  '59 degrees, relative humidity 66%, wind 25 mph'
#  '38 degrees, relative humidity 76%, wind 23 mph'
#  '65 degrees, relative humidity 90%, wind 15 mph'
#  '56 degrees, relative humidity 60%, wind 18 mph'
#  '83 degrees, relative humidity 73%, wind 7 mph'
#  '52 degrees, relative humidity 82%, wind 21 mph'
#  '52 degrees, relative humidity 81%, wind 13 mph'
#  '44 degrees, relative humidity 59%, wind 11 mph'
#  '48 degrees, relative humidity 74%, wind 11 mph'
#  '57 degrees, relative humidity 63%, wind 7 mph'
#  '38 degrees, relative humidity 88%, wind 8 mph'
#  '72 degrees, relative humidity 84%, wind 3 mph'
#  '53 degrees, relative humidity 67%, wind 6 mph'
#  '65 degrees, relative humidity 67%, wind 7 mph'
#  '45 degrees, relative humidity 19%, wind 7 mph'
#  '69 degrees, relative humidity 65%, wind 5 mph'
#  '48 degrees, relative humidity 52%, wind 7 mph'
#  '52 degrees, relative humidity 50%, wind 4 mph'
#  '70 degrees, relative humidity 83%, wind 1 mph'
#  '52 degrees, relative humidity 40%, wind 8 mph'
#  '54 degrees, relative humidity 32%, wind 2 mph'
#  '38 degrees, relative humidity 33%, wind 6 mph'
#  '81 degrees, relative humidity 50%, wind 5 mph'
#  '37 degrees, relative humidity 59%, wind 13 mph'
#  '60 degrees, relative humidity 94%, wind 16 mph'
#  '36 degrees, relative humidity 68%, wind 14 mph'
#  '35 degrees, relative humidity 80%, wind 5 mph'
#  '81 degrees, relative humidity 64%, wind 5 mph'
#  '52 degrees, relative humidity 68%, wind 1 mph'
#  '39 degrees, relative humidity 46%, wind 18 mph'
#  '51 degrees, relative humidity 83%, wind 4 mph'
#  '34 degrees, relative humidity 64%, wind 9 mph'
#  '41 degrees, relative humidity 70%, wind 9 mph'
#  '34 degrees, relative humidity 58%, wind 10 mph'
#  '38 degrees, relative humidity 54%, wind 9 mph'
#  '70 degrees, relative humidity 67%, wind 7 mph'
#  '34 degrees, relative humidity 70%, wind 1 mph'
#  '44 degrees, relative humidity 73%, wind 5 mph'
#  '59 degrees, relative humidity 58%, wind 15 mph'
#  '69 degrees, relative humidity 83%, wind 2 mph'
#  '81 degrees, relative humidity 56%, wind 8 mph'
#  '78 degrees, relative humidity 63%, wind 5 mph'
#  '43 degrees, relative humidity 90%, wind 8 mph'
#  '57 degrees, relative humidity 49%, wind 10 mph'
#  '35 degrees, relative humidity 71%, wind 11 mph'
#  '34 degrees, relative humidity 51%, wind 18 mph'
#  '47 degrees, relative humidity 22%, wind 24 mph'
#  '33 degrees, relative humidity 85%, wind 5 mph'
#  '46 degrees, relative humidity 86%, wind 5 mph'
#  '39 degrees, relative humidity 78%, wind 3 mph'
#  '79 degrees, relative humidity 65%, wind 9 mph'
#  '43 degrees, relative humidity 69%, wind 8 mph'
#  '36 degrees, relative humidity 82%, no wind'
#  '43 degrees, relative humidity 63%, wind 10 mph'
#  '49 degrees, relative humidity 44%, wind 8 mph'
#  '55 degrees, relative humidity 60%, wind 5 mph'
#  '37 degrees, relative humidity 42%, wind 5 mph'
#  '37 degrees, relative humidity 65%, wind 6 mph'
#  '38 degrees, relative humidity 48%, wind 3 mph'
#  '41 degrees, relative humidity 46%, wind 6 mph'
#  '45 degrees, relative humidity 89%, wind 2 mph'
#  '28 degrees, relative humidity 88%, wind 15 mph'
#  '41 degrees, relative humidity 90%, wind 4 mph'
#  '65 degrees, relative humidity 77%, wind 4 mph, wind chill 0'
#  '35 degrees, relative humidity 93%, wind 1 mph, wind chill 0'
#  '39 degrees, relative humidity 79%, wind 10 mph, wind chill 0'
#  '38 degrees, relative humidity 91%, wind 7 mph, wind chill 0'
#  '33 degrees, relative humidity 85%, wind 6 mph, wind chill 0'
#  '33 degrees, relative humidity 75%, wind 5 mph, wind chill 0'
#  '57 degrees, relative humidity 80%, wind 2 mph, wind chill 0'
#  '32 degrees, relative humidity 85%, wind 7 mph, wind chill 0'
#  '53 degrees, relative humidity 19%, wind 10 mph, wind chill 0'
#  '35 degrees, relative humidity 88%, wind 6 mph, wind chill 0'
#  '38 degrees, relative humidity 92%, wind 10 mph, wind chill 0'
#  '34 degrees, relative humidity 59%, wind 6 mph'
#  '39 degrees, relative humidity 91%, wind 1 mph'
#  '40 degrees, relative humidity 47%, wind 10 mph'
#  '33 degrees, relative humidity 63%, wind 1 mph'
#  '34 degrees, relative humidity 72%, wind 1 mph'
#  '35 degrees, relative humidity 69%, wind 13 mph'
#  '34 degrees, relative humidity 81%, wind 13 mph'
#  '40 degrees, relative humidity 62%, wind 13 mph'
#  '29 degrees, relative humidity 75%, wind 10 mph'
#  '40 degrees, relative humidity 70%, wind 7 mph'
#  '63 degrees, relative humidity 78%, wind 9 mph']
# ['grass ' 'grass' 'fieldturf ' 'fieldturf' 'sportturf' 'matrixturf'
#  'a_turf' 'astroturf']
# [85. 84. 90. nan 79. 74. 76. 61. 66. 60. 72. 82. 81. 80. 88. 68. 64. 86.
#  67. 89. 91. 73. 65. 62. 59. 56. 75. 58. 57. 49. 70. 69. 54. 47. 55. 63.
#  71. 53. 45. 43. 36. 41. 46. 38. 42. 40. 50. 48. 44. 33. 32. 39. 37. 21.
#  27. 28. 77. 35. 26. 31. 11. 24.  1. 18. 52. 17. 14. 87. 83. 78. 29. 22.
#  51. 10. 23. 19. 13. 16. 92. 97. 25. 34. 93.]
# ['12%' '44%' '55%' nan '40%' '42%' '51%' '47%' '68%' '41%' '56%' '65%'
#  '86%' '70%' '66%' '60%' '74%' '39%' '15%' '36%' '63%' '53%' '84%' '0%'
#  '37%' '49%' '58%' '77%' '59%' '91%' '89%' '73%' '80%' '34%' '18%' '35%'
#  '61%' '93%' '54%' '79%' '62%' '100%' '83%' '46%' '48%' '50%' '17%' '78%'
#  '90%' '92%' '19%' '71%' 'mph' 'wind' '69%' '82%' '52%' '45%' '75%' '67%'
#  '14%' '87%' '85%' '33%' '57%' '11%' '72%' '43%' '38%' '9%' '7%' '20%'
#  '64%' '32%' '88%' '28%' '8%' '95%' '29%' '81%' '30%' '22%' '76%' '97%'
#  '23%' '94%']
# ['0 mph' '8 mph' '3 mph' nan '7 mph' '4 mph' '9 mph' '5 mph' '2 mph'
#  '1 mph' '6 mph' ' wind']
# ['outdoors' 'dome' 'retractable roof (closed)' 'retractable roof (open)']
# [nan 18.  0. 22. 15. 24. 20. 27. 23. 16. 19. 12. 34. 25. 28. 31. 30. 17.
#   1.  6. 32. 29. 26. 21.  9. 11. 14.  3. 36.  7. 13.  5.  4. 33. 39. 37.
#  38. 35.  2. 40. 41. 10. 43.  8. 42. 45. 47.]
# [nan 26.  0. 33. 22. 39. 34. 32. 35. 29. 30. 37. 48. 36. 41. 42. 38. 43.
#  47. 45. 28.  1. 54. 40.  9. 46. 44.  4. 52. 24. 50. 31. 17. 12. 19. 25.
#   5. 58. 23. 49. 27.  7. 11.  3.  8. 18.  2.  6. 56. 15. 53. 14. 59. 20.
#  62. 13. 21. 10. 51. 16. 55. 68. 61. 57.]
# [ nan 178.   0. 194. 258. 111. 320. 199. 334. 281. 231. 216. 189. 366.
#  278. 190. 363. 243. 271. 236. 423. 319. 186. 385. 340. 227. 207. 264.
#  329. 300. 170. 130. 297.  10. 374. 259. 260. 302. 238. 268. 232.  92.
#  387. 353. 364. 292. 368. 263. 304.  11. 239. 254. 299. 396. 266. 197.
#  220. 286. 213. 157.  78. 103. 196. 119. 287. 262.   3. 171. 206. 312.
#   35. 244. 205. 214. 350. 296.  31. 249. 405.  65. 331. 326. 301. 257.
#  237. 188. 248. 317. 376. 240. 234. 246. 202. 298. 261. 309. 503. 165.
#  172. 183. 223. 179.  68. 288.  37. 245. 321. 162. 124. 322. 397.   5.
#  182.  62. 406. 180. 191. 163. 380. 255. 210. 184. 267. 269. 359. 219.
#  230. 187. 284. 336.   1. 270. 252. 403. 307. 465. 225. 224. 294. 247.
#  335.  12. 174.  81.  49. 291. 200. 138. 204. 221. 308. 100.  82. 367.
#  120.  95. 273. 371. 143. 222. 342. 131. 337. 458. 212. 315. 341.   4.
#  228. 127. 513. 265. 253.  43. 276. 303. 290. 169. 198. 195. 449. 289.
#  242. 310.  50.   6. 139. 147. 250.  48.  16. 318. 389. 279. 277. 176.
#  125.   2.  22. 347. 168. 161. 338. 355. 392. 466. 102. 346. 332. 356.
#  447. 343. 369. 328. 325. 209. 283.  96.  21. 357. 229. 314. 251. 324.
#  151. 140.  18.  61. 384. 330. 101. 164.  67. 215. 280. 145. 282. 434.
#   51. 241. 160. 173. 175.  63. 159. 158. 113.  19. 181.  93.  83. 226.
#  114. 137. 323. 218. 349. 505. 373. 117.  15. 439. 417. 153.  14. 272.
#   36. 133. 419. 464. 375. 442. 208. 275. 395. 177.  84. 233. 149.  28.
#  156. 379. 399.  44. 391. 285.  -2.  85. 118. 136. 192.   8. 377. 455.
#  132. 108. 116.  45.  32.  87.  40. 107. 235. 201. 203.  98.  75. 378.
#  185.  55. 313. 418. 333. 306.  17. 166. 370. 311. 154. 146. 293.  89.
#   97. 112. 443.  38.  24.  29. 351. 422. 150.   7. 517.   9. 193. 426.
#   13. 122. 348. 211. 463.  20. 400. 295. 144.  76.  77.  23. 104. 429.
#   86.  33. 460. 372. 305.  59. 167. 358.  26. 446. 256. 148. 444. 424.
#  115. 129. 327.  39. 365. 105. 134. 456. 152. 128. 352. 126.  72.  88.
#  388. 450. 155. 316. 415. 217. 339.  71. 472.  53. 502. 360.  60.  74.
#   94.  46.  64. 416. 123. 390. 274. 106.  30. 344.  25. 345. 462. 402.
#  381.  79. 109.  69.  27. 393.  57. 121.  34. 361. 501.  66.  56.]
# [nan  1.  0.  2.  4.  3.  5.]
# [nan  2.  0.  1.  4.  3.  6.  5.]
# [nan  2.  0.  3.  4.  1.  5.  7.  8.  6. 10.  9.]
# [nan 19.  0. 18. 33. 16. 20. 12. 31.  1. 42.  8. 22. 10.  4. 36. 17.  7.
#   9. 14.  6. 15. 27. 13. 32. 21. 30. 64. 26.  2. 11. 35.  5. 29. 44. 23.
#  24.  3. 40. 28. 34. 25. 47. 38. 43. 55. 37. 39. 50. 53. 59. 56. 41. 71.
# ...
#  147.4  61.2  79.7 124.5 119.7  22.2  42.3 100.2  26.  101.2  18.7  55.1
#  122.6 116.2  81.5 118.4  77.7  92.3  92.7  99.1 120.2 121.2 107.1  44.6
#   13.7 155.2 101.5  68.3  64.  115.5 154.9  87.3 107.9  69.4  98.7  31.8
#   58.9 138.9  52.9  51.6  40.8 134.9 107.  106.1 138.5  64.2 121.7   3.3
#   62.9   6.9  67.5  83.1 144.8 154.2 113.8 127.4  60.8  73.3  85.7 138.
#   69.2  72.   21.7  85.   30.8 119.3 135.  141.9 105.4  99.8  22.7  55.8
#   51.8 122.5 152.8 141.1  36.7  26.9 138.2  12.5  77.4  32.8  45.  109.8
#  145.4  24.1 144.1 102.6 150.5 120.3  75.8  74.5 148.6 103.9 136.7 121.4
#  101.9 142.2   5.6   9.9 153.7  75.9  19.6 114.8  31.7  11.5  37.3  28.6
#  133.6  42.7  41.4 140.2 131.4 100.3 151.   34.3 147.6 103.7  85.6 135.8
#   51.7 150.2  15.8 150.6  48.3 142.3 139.7  32.7  28.5 104.4   9.2 120.6
#  148.3  68.5 136.4 140.5  75.2  27.9  41.2 122.3  43.2 103.   35.6  57.2
#   62.1  27.4 142.6 129.8 135.7 156.8  37.9 139.2 128.1 139.9  41.5  65.1
#  130.  157.3 147.2  31.   65.7  73.2 119.5  54.8  42.6  15.   22.   59.5
#   60.6 123.3 148.1  48.4 158.  131.5  57.7  80.  152.3  63.2 104.8  38.3
#  117.  140.   66.1  45.5 100.6 138.7 121.8 110.1  60.1  38.5 139.3  77.5
#   50.5  98.9  25.5  22.5  63.6  52.6 148.9 108.1  71.6  10.9  45.3  78.6
#   77.2   6.  127.6 106.4  62.  130.3  10.4 154.   46.8  95.7  10.1  20.3
#   69.5 132.6  43.  149.1  89.8  98.1 118.2  39.2  78.8  85.2 124.1  21.2
#   74.2 142.5  42.9 123.7  76.8  49.1  93.  146.3 119.1  37.8  52.4  21.8
#  127.3  42.2  38.2  48.5  23.7 146.7  21.9 116.5  38.6  61.9  42.   54.7
#  133.   80.3  71.7 120.  117.1  63.8 127.5 133.1   7.   38.7  76.7 107.4
#   66.8]
# [nan  0.  1.  2.]
# [nan  4.  6.  7. 13.  1.  0.  3.  5.  8. 10.  2.  9. 12. 11. 15. 14. 17.
#  19. 16.]
# [nan  3.  4.  2.  1.  0.  5.  8.  6.  9.  7. 11. 10. 12. 13.]
# [nan '75.0%' '66.7%' '28.6%' '30.8%' '100.0%' '0.0%' '83.3%' '40.0%'
#  '50.0%' '71.4%' '80.0%' '33.3%' '25.0%' '44.4%' '60.0%' '57.1%' '88.9%'
#  '62.5%' '87.5%' '85.7%' '77.8%' '55.6%' '72.7%' '73.3%' '42.9%' '90.9%'
#  '16.7%' '81.8%' '54.5%' '90.0%' '46.2%' '14.3%' '20.0%' '63.6%' '22.2%'
#  '10.0%' '53.8%' '61.5%' '70.0%' '12.5%' '45.5%' '36.4%' '38.5%' '41.7%'
#  '58.3%' '37.5%' '76.9%' '64.3%' '64.7%' '23.1%' '58.8%' '78.6%' '53.3%'
#  '84.6%' '57.9%' '91.7%' '30.0%' '68.8%' '69.2%' '81.3%' '18.2%' '46.7%'
#  '47.1%' '11.1%']
# [ nan  32.  76.  17.  77.  -7.  49.  11.   4.  57.  88.  45.  18.  14.
#    8.  46.  37.  29.  21.  55.  40.  26.  13.  56.   6.  95.  19.  22.
#   -6.  79.  15.  68.  35. 115. 136.   3.   2.  20.  99.  78.  -1.  98.
#   59.  38.  31.  27.  54.  16.  51.  10.  12.  43.  41.  67.  62.   7.
#   48.  50.  24.  44.  39.  52.  34.  42.  30. 102.   9.  61.  60.  47.
#   -3. 105.  64.  70.   5.  71.  87.  82.  33.  75.  63.  28.  25.  23.
#   80.   0.  69. 148.  53. 188.  83.   1.  93. 125.  66.  74.  86.  89.
#   72.  96. 118.  58.  -5. 224.  -8. 132.  36. 100. 130.  97.  65.  81.
#  107. 114. 146.  -4. 101.  73. 149.  92. 140. 110. 119. 116.  90.  85.
#  113. 150. 121. 122.  94. 108. 124. 137.  -2. 117. 109. 139. 106. 103.
#  144. 127. 123.  91. 158. 173.  84. 120. 104. 135. 201. 112. 227. 143.
#  163. 155. 154. 142. 131. 126. 166. 185. 134. 171. 151. 111. 157. 138.
#  145. 159. 156. 162. 128. 133. 164. 222. 168. 160. 147. 204. 129.]
# [ nan 10.7 19.   8.5 19.3 -7.  16.3  5.5  4.  11.4  2.   5.7 29.3 11.3
#  18.   7.   8.   5.8  9.3  7.7 10.5  7.4 11.  10.  26.  13.  56.  16.
#   6.  23.8 14.   6.3 22.  13.3 -6.  19.8 15.  34.  35.  28.8 17.   3.
#  20.  32.  11.1 11.2 -1.  11.8  9.5 10.3  8.7 12.3  9.  26.3 27.   4.3
#   5.  12.8 19.7 12.  18.5  5.4 20.5 13.4 15.5  9.8 51.  15.4  7.3  1.5
#  21.  25.5  4.5 15.3  5.3  8.6  7.8 -3.  17.6  6.5 64.   6.7 14.5  8.8
#  12.7 10.1 19.4 21.8 27.3  6.6 17.5 24.   8.2 12.5 13.5 31.5 12.4 28.
#  16.7  7.6 11.7  7.5 30.  14.7  2.5  0.  13.8  3.3 15.6 23.5 11.5 14.3
#  49.  15.8  6.8 17.1 10.4 16.5 13.7  0.5 23.  33.   6.4 24.8 21.5 12.2
#   1.   8.3  9.6  2.7 13.6 10.8 19.2  2.8 13.1 18.3  4.8 12.6 33.5 -2.5
#  -8.  14.8 36.   3.6 25.   4.7 97.  21.7 55.  20.3  5.2 -5.   3.5 44.
#  11.9 15.7 40.5  9.1 20.9 19.5 -4.  31.  37.   9.2 33.7 16.4  8.4 38.5
#   9.4 29.8 20.8 22.5 29.   7.2 14.2  3.4 45.  76.  48.   9.7 27.7 17.3
#  17.7  5.6  4.4 -0.5  8.9 22.6 16.8 43.  57.  26.5 40.  18.8  1.3 15.2
#  22.7 32.5 38.3 38.  53.  10.2 18.6  3.7 10.9  8.1 18.7 11.6 16.2  3.8
#   6.2 12.9 47.  68.  -2.  18.4 18.2 13.2 20.7 20.6 14.6 29.7 24.3 15.1
#  10.6 14.1 21.3 24.5  2.3 22.8 35.5 34.8 15.9 33.3 20.2 13.9  5.1 24.6
#  46.  27.5  4.2 41.  14.4 26.7 17.8 58.  23.7 14.9  6.1 50.  29.5  7.9
#   4.6 39.  22.3 17.2  1.8 27.2  3.2 23.3 24.7 25.3 59.  65.  39.7 28.5
#  37.7 20.4  7.1  1.7 37.5 34.5 17.4 -1.5 26.2 24.2 39.5 42.   5.9 28.3
#  28.7 25.7 30.3 75.  18.9 41.7 30.2 26.8 30.5 27.8  6.9 16.6 27.6 16.1
#  24.4 21.4 18.1 69.  45.5  0.7 19.9  4.9 72.  34.7 22.2 25.6 70.  36.5
#   9.9 12.1 25.2  0.3 52.  23.4 29.6 54.  21.6 28.4 31.3 21.2 92.   0.8]
# [ nan  8.  12.7  2.4  5.9 -7.  12.3  3.7  0.   4.   9.5  0.8  4.3 29.3
#  11.3 18.   4.7  5.8  9.3  2.9  7.   5.3  7.9 26.   6.5 18.7  6.2  3.
#  10.6 14.   3.2  7.4  7.3  6.  -6.  15.  34.  35.  19.2 15.1  1.5  2.
#  20.   6.3 16.  11.  11.1 11.2 -1.   8.4  5.5  5.2  8.2  6.8 26.3 13.5
#   1.8  4.4  3.4  3.8  8.5  3.3 19.7 12.   6.7  6.9  9.   1.  17.  13.
#   7.7 21.  10.   8.8 12.8  4.1  5.  12.2  4.2  4.5  8.6 13.2 -3.  12.6
#   0.5  5.7  4.8 21.3  2.3  9.7  7.2 19.   8.9 17.4 27.3 11.7 24.  12.5
#  15.8 12.4  8.3  5.4 10.8  3.5 30.  -0.5 -0.3 14.7  2.5  9.9  8.7 23.5
#   9.2 10.5 14.8 49.   7.1 10.3  4.6  6.4  6.1 22.   7.5 13.3 11.5  2.6
#   5.6 10.4 23.   9.6 33.   7.8  9.8 13.8 15.6 21.5  2.7 11.8  2.8 10.7
#  16.7  1.7 19.3  0.3 16.8  1.9 27.   6.6 -2.5  1.3 32.  -8.  46.   3.1
#  14.3 17.5 21.7 24.3  9.4 19.5  3.6 18.3 11.6  0.7 13.7 -5.  44.  15.7
#  13.1 20.3  9.1 16.2 -4.  31.  37.  33.7 17.3 23.8 14.6 24.8 14.5 15.4
#   4.9  3.9 23.2 14.2 10.2 25.  10.1 15.3 28.  15.5 45.  10.9  1.6 27.7
#  17.7  8.1 22.6 26.5 40.  18.5 15.2 32.5 38.  53.  13.4  7.6  2.2 20.7
#  43.   1.1  0.6  5.1 -2.  18.4 36.  11.9 12.9  1.2 16.5  2.1 29.7 20.5
#  12.1 47.  35.5 27.8 14.4 20.8 17.6 18.2 27.5 41.  11.4 24.5 17.8 58.
#  25.5 13.6 16.9 23.7 22.5 -2.7 29.   1.4 23.6 18.1 -0.7  0.4 37.5 21.8
#  39.  22.7 22.3 59.  65.  26.7 39.7 37.7 14.9 23.4 -0.4 16.4 34.5 -1.5
#  21.6 24.2 31.5 28.3 17.2 16.3 23.3 30.3 20.6 17.1 31.3 26.8 16.6 30.5
#  20.2 75.  51.  16.1 25.3 22.4 69.  29.8 33.5 24.7 42.  19.8 15.9  0.9
#  13.9 29.5 70.  40.5 -1.7 50.  52.  19.6 54.  -1.3 33.3 24.4 26.4 17.9
#  21.2 45.5]
# [nan  0.  1.  2.  3.]
# [  nan  97.9 109.7  39.6  52.4  79.2 115.6  72.9   0.   83.3 106.2   8.3
#   82.3 158.3 153.1 118.7  77.1 100.   90.6 105.2 128.1  56.2  86.8  83.6
#   54.8  70.8  81.9  43.7  43.5  65.6  56.9 137.1  45.1  54.9  85.4  96.7
#  149.3  95.8 149.5 152.7 113.3 155.2 117.5  73.7  91.7 132.3   2.8  82.8
#   80.8  80.2  16.7 132.6  71.5 112.5 116.7 121.9  10.   45.   11.9  71.7
#   28.2 104.2  42.4 108.3  24.4 129.2  84.7 121.5  75.8 136.8 102.1  59.7
#  103.3 135.4  78.9  87.5  70.1  84.2  86.5 142.  134.2  68.2 113.7 116.9
#  100.8  80.   93.1  93.7  65.4  81.2  94.4  64.6 137.5 134.4  96.5 136.3
#   60.4  91.  113.9 143.2  84.  101.8  57.3  89.6  42.9 122.9  42.7 118.3
#  142.7  92.4  88.5  59.  101.   97.1  58.3  62.5  59.4  74.3  90.8  71.9
#  134.7  88.9 102.7  84.5  81.6 105.   90.3 110.4  92.5 149.  103.1 111.1
#  152.1 110.8  79.5  97.3  37.1  99.3 127.1 128.8 127.8 115.3 114.2  87.2
#   61.2 103.5 107.3  75.  133.3  72.3  88.2 114.6  45.8  80.4 113.5  61.
#  149.7 106.7  44.8 120.2  95.3  96.9  79.9  49.   96.4 125.   52.1 110.7
#   57.9  90.2 117.7  63.7 147.5 111.5  92.6 155.4 138.5  97.2 141.7  23.1
#   66.   46.5  83.9  82.5 143.7 104.7 102.8 142.1  12.   34.6  41.7  94.
#   66.7 105.6  80.7 148.6 126.2  92.7 138.2 156.2  79.7  65.  145.4  42.5
#   58.6  52.7  48.7 100.7  32.3 140.6 120.8 111.2  27.5  95.1  51.6 146.8
#  141.  102.9 144.3 155.8 115.5  87.1  50.  110.  124.3 145.1  62.9 145.8
#   94.8 134.6  51.2  74.6  67.7 101.2  61.5  96.   69.4  82.1 131.8  35.8
#   93.3  68.7  78.7  57.6  88.4 132.1  53.5  41.1 126.7 130.6 109.5  91.4
#  154.2  46.9  41.2 107.1  94.6 113.2  65.3  33.3  98.6  82.6 153.3  71.2
#   75.7  65.8 126.6  47.9 136.2  19.4  86.1 148.5 108.   86.2 150.4 149.6
#  105.7 109.4  50.9 150.7  14.3 101.4  13.5  99.6  53.9  77.8  95.  102.4
#   99.   82.9  15.8  50.4  84.4 140.2  76.8  50.7 134.  111.7 123.6  42.1
#   55.4  53.1  76.   51.8 146.5  65.2 136.9  37.5  81.7  94.3  63.5 106.9
#   74.4  90.  111.4  88.7  61.6  98.8 109.2  55.8  63.2  89.2  25.   67.9
#   97.4 104.9  98.4  80.9  62.8  89.9 113.6  86.7  51.4  83.7  20.8 104.4
#   73.4  96.8 150.   30.6  28.7  75.2  29.2  70.6  52.5  49.8  74.1 155.1
#   89.4 119.5 118.1  19.8 131.2  81.8  62.7  67.1  18.1 138.7  69.3  55.7
#   66.2  53.2 112.   99.2 112.7  66.4  61.1  99.8 116.  147.9  67.4  54.2
#  140.5  95.6 119.  115.   18.7  62.2 145.3  67.6 118.2 146.9 141.2  90.1
#  101.7  49.3  87.9 111.3   7.3  99.4 109.   10.7 131.  122.2  72.4  96.1
#   58.1 102.6  59.6 139.6 104.   86.6 100.3  73.6  58.9  77.9 123.7 109.9
#   96.2  43.1 154.6  10.4 111.8 151.4  12.5 134.5 141.1 146.3   9.6  35.4
#   81.  103.4  75.4  73.8  98.7  83.  117.9  27.1 109.8 128.5 138.9  92.1
#  109.1   3.   73.5  78.5  88.1 107.6  62.1  52.6  94.2 125.6 107.7 136.5
#   69.1  54.7 141.4  84.8 129.3  50.3  76.4 140.4  81.5 119.8  60.9 127.4
#  151.   40.4  45.4  92.  102.3  64.1  55.   80.5  42.6  62.   36.1 121.7
#   59.9 104.8 103.  157.3  13.3  87.8 105.1 113.1  51.7  21.9  99.1 103.7
#   88.3 117.4  85.8  69.8  63.4  23.6 152.6  98.5 136.1 129.9 125.7 134.9
#   85.9  61.8  52.9 123.9 143.1  51.5  49.6  22.9  53.3  75.3  97.6  56.8
#   69.6  34.3  26.9  74.  132.2  14.2  32.2  68.1  64.   70.5 155.6 157.9
#   11.1  77.7  43.2  78.1 106.8  94.9 133.7 143.3  70.4  64.2  79.6 107.5
#  148.4 106.   84.6  74.7  86.3 125.8 120.1 154.5 105.8  63.   53.   67.8
#   78.3  69.9 119.2  65.5 107.9  40.3  92.2 139.1 103.9 114.3  35.7  46.8
#   76.2  78.2   2.1  44.3 120.4  90.5 125.2  45.2 150.9 132.9  91.2 115.4
#  102.5 134.3 142.4  24.  115.8 122.5 138.4 126.4 112.1 142.9  28.3  80.6
#   98.3 130.7 128.3  76.5 101.6 142.6  87.   71.1 109.3 121.4 147.3 126.9
#   59.2 113.   60.  152.5 131.5  74.8  22.6  90.4  98.2  97.5  53.7  11.5
#   36.5  25.4 124.4  56.6 144.8 103.8 144.   67.5  60.8  59.5 106.6  92.3
#   68.   95.5 133.1 103.6  31.2  37.   72.5 126.5 101.5  39.2  92.9  33.2
#  100.9   3.6  86.  123.3  38.5 143.9 129.8 157.4  44.2  39.1  30.   38.8
#   34.   77.5  78.6  11.8  69.2 118.5  42.2 127.9  82.4  89.  123.2  46.4
#   51.  104.6 117.3 144.4 122.   19.6 129.6 142.5 119.6  72.2  19.9  36.7
#  131.9 110.9  75.9  97.   70.3 154.9  44.4  40.6 153.7   7.9 108.9  93.2
#  111.6 135.   34.4  32.6  17.4  80.1 139.3   1.8  27.4 105.4  48.6  85.
#   95.4  88.  140.   20.1 121.2 157.1 120.  122.1 117.6 107.4  67.   73.3
#   53.6  76.7  79.3  55.3 153.5   6.9  57.8   6.2  84.9 100.5  13.  130.8
#  121.1  35.9 119.4  31.7  83.8  54.6  55.2  89.1  78.   72.1  55.9  58.7
#  157.6  38.9  35.  103.2  24.1 118.4  47.4  10.8  30.2  57.4 124.   73.9
#  111.9  93.4 135.2 146.7 127.3  86.9   9.9  38.3 140.1 146.2 128.6  26.
#   63.9   4.2 112.3  93.5  95.2 128.7  20.3 140.7 135.1  15.6 140.9  60.2
#   26.4   4.8  79.8  48.8  28.1  67.2 116.4 129.4 116.2 142.3 126.   99.5
#    5.6  34.2  57.1 108.6 105.9  96.6  26.5  92.8 110.2 119.3  50.5 152.9
#   99.7  21.3 135.9  65.1 156.8  77.4 125.5 104.5  66.1  70.   48.3 132.4
#  127.2 146.1  62.3 124.6 138.3  41.  156.6  50.8  61.7  91.1  29.7  36.9
#  133.9 150.5 131.7  54.3  32.5  42.8 122.7 123.4 112.8  21.8  46.2 132.5
#   87.6  56.  100.4   4.9  49.4 130.2 115.1  60.1  34.5  98.1 142.8  59.3
#    9.7  63.3 108.8 129.7  77.6  40.8 139.8 154.7 114.8  34.7 150.2 153.6
#  133.8  38.2 152.8  58.   40.1  23.2 134.8 113.4 147.7 130.4 148.7 145.5
#   63.1 149.1  44.1  29.8 137.2  47.6 122.6  75.5  74.5 137.9 151.6  59.8
#  123.8  24.3 156.9 106.5 135.8 125.3  44.6  50.6  57.2]
# [  nan  10.3  17.3   8.4  15.9  -7.   11.8   3.   11.    4.   -2.2   6.2
#    7.   14.7   6.5  15.    1.3  -6.    0.3   7.5   5.    9.2   8.7   4.1
#    2.1   6.8  26.   10.   18.3   2.8  14.1  15.5   7.2  16.3   3.5   3.4
#   14.   20.3  15.3  -0.6  -5.    9.9   0.    8.   23.5  19.   14.2  17.4
#    9.    1.5  -2.   -3.    9.7  14.5   4.7  13.3   8.5   4.4   3.2   3.8
#   -4.    6.    1.   20.8  13.   11.5   4.3   2.    2.5  -1.    0.5  18.
#   19.3  11.2   6.3   2.3  11.9   7.8   9.8   1.7  14.9   6.1  19.9  -1.5
#    5.5   5.6   7.9   9.6  17.8   4.5   7.7   3.7  13.5   4.2   0.7   2.4
#   21.    5.3  21.5  12.    9.3   5.7  12.4   2.2  11.3  16.   22.3   7.3
#   16.7  11.4  16.4   3.3   7.6  10.8  41.    1.8  14.8   9.5  17.   16.5
#   11.7  34.7  12.3  -0.5  33.    4.6   4.8  -2.5  14.3  26.3  12.2  46.
#    5.9  10.5   6.7   2.7  16.6  -4.5   8.9  11.6  23.    8.8  22.   10.2
#    0.8  28.   44.   53.   -4.6   5.2  25.   10.4   7.4   8.6  18.5  10.7
#   15.6  20.6  -0.3   8.3  -0.2  17.7  12.7  21.3  12.1   7.1   2.9  -1.3
#   -9.   21.7  38.   18.7  15.2  24.    9.4  20.   -0.7  39.   13.7  10.6
#   12.9  17.5  -1.8  25.5   5.4  -6.5   5.1  -0.9  12.8  13.8  15.7   5.8
#   24.8  -3.7  36.   17.6   6.4  -1.7  19.8  12.5  19.7  16.8   1.2   3.6
#   23.3   6.6  40.   10.1  13.4  18.6  19.5  11.1  13.2  12.6  -3.3  27.7
#   27.   29.   16.1  14.6  19.6  51.   31.    1.6  18.2  20.1   8.1   0.6
#   35.   50.    0.4 -10.    8.2  -8.    2.6  42.   24.3  37.   14.4  20.5
#   -2.3  18.4  32.   22.7   9.1  -3.5  30.   34.   23.8  27.5  30.5  13.9
#   22.2  43.   -2.8  28.3   1.9  16.2  15.8  24.2  28.7  21.8  -0.8  26.4
#    1.1  24.5  13.6  17.2  22.4   1.4  24.7  25.3   3.1  10.9  13.1  25.6
#   21.4  22.5  26.5  -3.4  -2.7  21.9  20.7  -4.3  19.2  37.5   0.2  18.8
#   21.6  20.2   4.9  36.5  47.   27.3   3.9  21.2  -1.1  23.2  28.5  39.5
#   26.8   0.9  19.4  29.8  59.   -1.4  29.3  35.5  17.9  15.4  -0.4   0.1
#   32.5  33.5  23.6  34.5  15.1  23.4  20.4  31.5  22.8  23.9  26.2  25.2
#   31.3  16.9  52.   17.1  50.5  -1.6  -1.2  29.7   6.9  22.1 -11.   -3.8
#   -5.7  26.6  30.6  25.7  27.2  28.6  -5.5  45.   49.   25.9  29.2  58.
#   -7.5]
# [ nan  25.  56.  13.  69.  -7.  37.   8.   4.  -5.  -2.   9.  44.  26.
#   15.  -6.   2.  30.  17.  21.  18.   6.  29.  11.   3.   1.  10.  14.
#   12.  22.  47.  19.  79. 121.  -3.  27.  33.  50.  46.  34.  -4.   0.
#   41.  -1.  24.  54.   7.  36.  23.  20.   5.  45.  16.  95.  48.  42.
#   53.  28.  80.  67.  38.  32.  96.  61.  52.  35.  39. -10.  40.  91.
#   59. 132.  31.  -9.  94. -23.  43.  57.  62.  60.  84.  51. 144. 111.
#   70.  81.  77.  -8.  90.  78.  49.  55.  65.  68. 108.  63.  89.  66.
#   58. -11. 123.  93.  73.  71.  74.  99.  76.  85. 100.  75.  64.  82.
#  119.  98. -12. 109.  72. 165.  92. -13. -31.  88. -14. 107. -15. 171.
#   86. 129. 102. 116. 103. 125. 126. 104. 118.  83. 122. 101. 120.  87.
#  106. 115. 114.  97. -17. -16. 172. 137. 112. -20.]
# [ nan   7.  20.   4.   8.   0.  12.   3.  62.   6.  44.  19.   1.  14.
#   29.  49.  11.   2.  26.  34.   5.  69.  13.  23.  -1.  42.  54.  21.
#   16.  36.  15.  72.  45.  31.  22.  61.  25.  27.   9.  17.  10.  40.
#   32.  28.  18.  -3.  35.  33.  38.  57.  24.  58.  56.  37.  30.  48.
#   39.  84.  52.  80.  70.  60.  63.  47.  81.  71.  83.  65.  43. 102.
#   55.  79.  78.  64.  51.  74.  -2.  46.  92.  67.  59.  41.  53.  68.
#   50.  -8.  82.  94.  90.  76.  97.  91.  66.  73.  -5. 153.  -6.  -7.
#   -4.  95.  93.  75.  99.  87.  85. 135.]
# [nan  1.  0.  2.  4.  3.  6.  9.  5.  7. 10. 13.  8. 35. 26. 11. 12. 16.
#  15. 21. 25. 27. 14. 17. 31. 18. 24. 22. 19.]
# [nan  0.  1.  2.  3.  4.  5.  9.  6.  7.  8.]
# [nan  0.  3.  2.  1.  4.  5.  6.]
# [nan 0.  1.5 1.  2.  0.5 2.5 3.  3.5 4.  5. ]
# [nan  0.  6.  1.  5.  3.  2.  4.  7.  9. 10.  8.]
# [nan  3.  6.  2.  4.  1.  0.  7.  9.  5. 11.  8. 10. 12. 13. 14. 17. 15.
#  18. 19. 16.]
# [nan  0.  1.  2.  3.  4.  5.  7.]
# [nan '0.0%' '14.3%' '25.0%' '12.5%' '10.0%' '50.0%' '9.1%' '20.0%' '16.7%'
#  '37.5%' '100.0%' '33.3%' '18.2%' '36.4%' '8.3%' '57.1%' '15.4%' '40.0%'
#  '66.7%' '27.3%' '30.0%' '11.1%' '42.9%' '23.1%' '28.6%' '60.0%' '75.0%'
#  '22.2%' '7.7%' '6.7%' '44.4%' '30.8%' '23.5%' '45.5%' '5.3%' '21.4%'
#  '7.1%' '6.3%' '5.0%' '15.8%' '62.5%' '18.8%' '13.3%' '5.9%' '38.5%'
#  '11.8%' '55.6%' '41.7%' '21.1%' '17.6%']

# %%
combined_data['wind'] = combined_data['wind'].replace(' wind', np.nan)

combined_data['wind'].unique()
# Out:
# array(['0 mph', '8 mph', '3 mph', nan, '7 mph', '4 mph', '9 mph', '5 mph',
#        '2 mph', '1 mph', '6 mph'], dtype=object)

# %%
# US vs non US stadiums - UPDATED
us_stadiums = [
    'Raymond James Stadium',  # Tampa, FL
    'Mercedes-Benz Stadium',  # Atlanta, GA
    'Highmark Stadium',  # Buffalo, NY
    'Bank of America Stadium',  # Charlotte, NC
    'Paul Brown Stadium',  # Cincinnati, OH
    'Lucas Oil Stadium',  # Indianapolis, IN
    'Nissan Stadium',  # Nashville, TN
    'Ford Field',  # Detroit, MI
    'NRG Stadium',  # Houston, TX
    'FedExField',  # Landover, MD
    'GEHA Field at Arrowhead Stadium',  # Kansas City, MO
    'MetLife Stadium',  # East Rutherford, NJ
    'TIAA Bank Stadium',  # Jacksonville, FL
    'Gillette Stadium',  # Foxborough, MA
    'SoFi Stadium',  # Inglewood, CA
    'Allegiant Stadium',  # Las Vegas, NV
    'Hard Rock Stadium',  # Miami Gardens, FL
    'Soldier Field',  # Chicago, IL
    'FirstEnergy Stadium',  # Cleveland, OH
    'Lincoln Financial Field',  # Philadelphia, PA
    'Heinz Field',  # Pittsburgh, PA
    'State Farm Stadium',  # Glendale, AZ
    'Lumen Field',  # Seattle, WA
    'M&T Bank Stadium',  # Baltimore, MD
    'Lambeau Field',  # Green Bay, WI
    'Empower Field at Mile High',  # Denver, CO
    'U.S. Bank Stadium',  # Minneapolis, MN
    "Levi's Stadium",  # Santa Clara, CA
    'AT&T Stadium',  # Arlington, TX
    'Caesars Superdome',  # New Orleans, LA
    'Paycor Stadium',  # Cincinnati, OH (renamed from Paul Brown)
    'Acrisure Stadium',  # Pittsburgh, PA (renamed from Heinz)
    'Cleveland Browns Stadium',  # Cleveland, OH (same as FirstEnergy)
    'EverBank Stadium',  # Jacksonville, FL (same as TIAA Bank)
    'Huntington Bank Field',  # Chicago, IL (part of Soldier Field complex)
    'Northwest Stadium',  # Maryland
    'Sports Authority Field at Mile High',  # Denver, CO (old name for Empower Field)
    'EverBank Field',  # Jacksonville, FL (old name for EverBank/TIAA Bank)
    'Georgia Dome',  # Atlanta, GA (old, replaced by Mercedes-Benz)
    'Arrowhead Stadium',  # Kansas City, MO (old name for GEHA Field)
    'Mercedes-Benz Superdome',  # New Orleans, LA (old name for Caesars Superdome)
    'CenturyLink Field',  # Seattle, WA (old name for Lumen Field)
    'University of Phoenix Stadium',  # Glendale, AZ (old name for State Farm)
    'New Era Field',  # Buffalo, NY (old name for Highmark Stadium)
    'Los Angeles Memorial Coliseum',  # Los Angeles, CA
    'Oakland-Alameda County Coliseum',  # Oakland, CA
    'Qualcomm Stadium',  # San Diego, CA
    'StubHub Center',  # Carson, CA
    'Ring Central Coliseum',  # Oakland, CA (alternative name for Oakland-Alameda)
    'Bills Stadium'  # Buffalo, NY (alternate name for Highmark/New Era)
]

# Non-US stadiums - UPDATED
non_us_stadiums = [
    'Tottenham Stadium',  # London, UK
    'Wembley Stadium',  # London, UK
    'Allianz Arena',  # Munich, Germany
    'Azteca Stadium',  # Mexico City, Mexico
    'Deutsche Bank Park',  # Frankfurt, Germany
    'Neo Quimica Arena',  # São Paulo, Brazil
    'Croke Park',  # Dublin, Ireland
    'Olympiastadion',  # Berlin, Germany
    'Estadio Santiago Bernabéu',  # Madrid, Spain
    'Twickenham Stadium'  # London, UK
]

# stadiums by time zone - UPDATED:

# Brasilia Time Zone
GMT_minus_3 = [
    'Neo Quimica Arena',  # São Paulo, Brazil
]

# Eastern Time Zone (ET) - GMT-5 - UPDATED
GMT_minus_5 = [
    'Raymond James Stadium',  # Tampa, FL
    'Mercedes-Benz Stadium',  # Atlanta, GA
    'Highmark Stadium',  # Buffalo, NY
    'Bank of America Stadium',  # Charlotte, NC
    'Paul Brown Stadium',  # Cincinnati, OH
    'Nissan Stadium',  # Nashville, TN
    'Northwest Stadium', # Maryland
    'Ford Field',  # Detroit, MI
    'FedExField',  # Landover, MD
    'MetLife Stadium',  # East Rutherford, NJ
    'TIAA Bank Stadium',  # Jacksonville, FL
    'Gillette Stadium',  # Foxborough, MA
    'Hard Rock Stadium',  # Miami Gardens, FL
    'FirstEnergy Stadium',  # Cleveland, OH
    'Lincoln Financial Field',  # Philadelphia, PA
    'Heinz Field',  # Pittsburgh, PA
    'M&T Bank Stadium',  # Baltimore, MD
    'Paycor Stadium',  # Cincinnati, OH
    'Acrisure Stadium',  # Pittsburgh, PA
    'Cleveland Browns Stadium',  # Cleveland, OH
    'EverBank Stadium',  # Jacksonville, FL
    'Lucas Oil Stadium',  # Indianapolis, IN
    'Georgia Dome',  # Atlanta, GA (Eastern Time)
    'New Era Field',  # Buffalo, NY (Eastern Time)
    'EverBank Field',  # Jacksonville, FL (Eastern Time)
    'Bills Stadium'  # Buffalo, NY (Eastern Time)
]

# Central Time Zone (CT) - GMT-6 - UPDATED
GMT_minus_6 = [ 
    'Lambeau Field', # Green Bay, WI
    'NRG Stadium',  # Houston, TX
    'GEHA Field at Arrowhead Stadium',  # Kansas City, MO
    'AT&T Stadium',  # Arlington, TX
    'Soldier Field',  # Chicago, IL
    'Huntington Bank Field',  # Chicago, IL
    'U.S. Bank Stadium',  # Minneapolis, MN
    'Caesars Superdome',  # New Orleans, LA
    'Azteca Stadium',  # Mexico City
    'Arrowhead Stadium',  # Kansas City, MO (Central Time)
    'Mercedes-Benz Superdome'  # New Orleans, LA (Central Time)
]

# Mountain Time Zone (MT) - GMT-7 - UPDATED
GMT_minus_7 = [
    'State Farm Stadium',  # Glendale, AZ
    'Empower Field at Mile High',  # Denver, CO
    'Sports Authority Field at Mile High',  # Denver, CO (Mountain Time)
    'University of Phoenix Stadium'  # Glendale, AZ (Mountain Time)
]

# Pacific Time Zone (PT) - GMT-8 - UPDATED
GMT_minus_8 = [
    'SoFi Stadium',  # Inglewood, CA
    'Lumen Field',  # Seattle, WA
    "Levi's Stadium",  # Santa Clara, CA
    'Allegiant Stadium',  # Las Vegas, NV
    'CenturyLink Field',  # Seattle, WA (Pacific Time)
    'Los Angeles Memorial Coliseum',  # Los Angeles, CA (Pacific Time)
    'Oakland-Alameda County Coliseum',  # Oakland, CA (Pacific Time)
    'Qualcomm Stadium',  # San Diego, CA (Pacific Time)
    'StubHub Center',  # Carson, CA (Pacific Time)
    'Ring Central Coliseum'  # Oakland, CA (Pacific Time)
]

# British Time Zone - GMT - UPDATED
GMT = [
    'Croke Park',  # Dublin, Ireland
    'Tottenham Stadium',  # London, UK
    'Wembley Stadium',  # London, UK
    # ADDED MISSING STADIUM:
    'Twickenham Stadium'  # London, UK (GMT/BST)
]

# Central European Time Zone - GMT+1 - UPDATED (NO CHANGE)
GMT_plus_1 = [
    'Allianz Arena',  # Munich, Germany
    'Deutsche Bank Park',  # Frankfurt, Germany
    'Olympiastadion',  # Berlin, Germany
    'Estadio Santiago Bernabéu',  # Madrid, Spain
]

# Team time zone mapping (based on home city)
team_timezones = {
    # Eastern Time (ET) - GMT-5
    'Atlanta Falcons': -5,  # Atlanta, GA
    'Baltimore Ravens': -5,  # Baltimore, MD
    'Buffalo Bills': -5,  # Buffalo, NY
    'Carolina Panthers': -5,  # Charlotte, NC
    'Cincinnati Bengals': -5,  # Cincinnati, OH
    'Cleveland Browns': -5,  # Cleveland, OH
    'Detroit Lions': -5,  # Detroit, MI
    'Indianapolis Colts': -5,  # Indianapolis, IN
    'Jacksonville Jaguars': -5,  # Jacksonville, FL
    'Miami Dolphins': -5,  # Miami Gardens, FL
    'New England Patriots': -5,  # Foxborough, MA
    'New York Giants': -5,  # East Rutherford, NJ
    'New York Jets': -5,  # East Rutherford, NJ
    'Philadelphia Eagles': -5,  # Philadelphia, PA
    'Pittsburgh Steelers': -5,  # Pittsburgh, PA
    'Tampa Bay Buccaneers': -5,  # Tampa, FL
    'Tennessee Titans': -5,  # Nashville, TN
    'Washington Redskins': -5,  # Landover, MD
    'Washington Football Team': -5,  # Landover, MD
    
    # Central Time (CT) - GMT-6
    'Chicago Bears': -6,  # Chicago, IL
    'Dallas Cowboys': -6,  # Arlington, TX
    'Green Bay Packers': -6,  # Green Bay, WI
    'Houston Texans': -6,  # Houston, TX
    'Kansas City Chiefs': -6,  # Kansas City, MO
    'Minnesota Vikings': -6,  # Minneapolis, MN
    'New Orleans Saints': -6,  # New Orleans, LA
    
    # Mountain Time (MT) - GMT-7
    'Arizona Cardinals': -7,  # Glendale, AZ
    'Denver Broncos': -7,  # Denver, CO
    
    # Pacific Time (PT) - GMT-8
    'Las Vegas Raiders': -8,  # Las Vegas, NV
    'Los Angeles Chargers': -8,  # Inglewood, CA
    'Los Angeles Rams': -8,  # Inglewood, CA
    'Oakland Raiders': -8,  # Oakland, CA
    'San Diego Chargers': -8,  # San Diego, CA
    'San Francisco 49ers': -8,  # Santa Clara, CA
    'Seattle Seahawks': -8,  # Seattle, WA
}

# If you also want time zone abbreviations
team_timezones_abbr = {
    # Eastern Time (ET)
    'Atlanta Falcons': 'ET',
    'Baltimore Ravens': 'ET',
    'Buffalo Bills': 'ET',
    'Carolina Panthers': 'ET',
    'Cincinnati Bengals': 'ET',
    'Cleveland Browns': 'ET',
    'Detroit Lions': 'ET',
    'Indianapolis Colts': 'ET',
    'Jacksonville Jaguars': 'ET',
    'Miami Dolphins': 'ET',
    'New England Patriots': 'ET',
    'New York Giants': 'ET',
    'New York Jets': 'ET',
    'Philadelphia Eagles': 'ET',
    'Pittsburgh Steelers': 'ET',
    'Tampa Bay Buccaneers': 'ET',
    'Tennessee Titans': 'ET',
    'Washington Redskins': 'ET',
    'Washington Football Team': 'ET',
    
    # Central Time (CT)
    'Chicago Bears': 'CT',
    'Dallas Cowboys': 'CT',
    'Green Bay Packers': 'CT',
    'Houston Texans': 'CT',
    'Kansas City Chiefs': 'CT',
    'Minnesota Vikings': 'CT',
    'New Orleans Saints': 'CT',
    
    # Mountain Time (MT)
    'Arizona Cardinals': 'MT',
    'Denver Broncos': 'MT',
    
    # Pacific Time (PT)
    'Las Vegas Raiders': 'PT',
    'Los Angeles Chargers': 'PT',
    'Los Angeles Rams': 'PT',
    'Oakland Raiders': 'PT',
    'San Diego Chargers': 'PT',
    'San Francisco 49ers': 'PT',
    'Seattle Seahawks': 'PT',
}

# %%
# Create dictionary with numerical time zone offsets (hours from GMT)
stadium_timezone_offsets = {}

# Add all time zone offsets
for stadium in GMT_minus_3:
    stadium_timezone_offsets[stadium] = -3  # GMT-3

for stadium in GMT_minus_5:
    stadium_timezone_offsets[stadium] = -5  # ET

for stadium in GMT_minus_6:
    stadium_timezone_offsets[stadium] = -6  # CT

for stadium in GMT_minus_7:
    stadium_timezone_offsets[stadium] = -7  # MT

for stadium in GMT_minus_8:
    stadium_timezone_offsets[stadium] = -8  # PT

for stadium in GMT:
    stadium_timezone_offsets[stadium] = 0  # GMT

for stadium in GMT_plus_1:
    stadium_timezone_offsets[stadium] = 1  # CET

print(f"Created mapping for {len(stadium_timezone_offsets)} stadiums")

# Add columns to your DataFrame
combined_data['time_zone_offset'] = combined_data['stadium'].map(stadium_timezone_offsets)
combined_data['is_international'] = combined_data['stadium'].isin(non_us_stadiums)

# Check for any stadiums not in the mapping
missing_stadiums = combined_data[combined_data['time_zone_offset'].isna()]['stadium'].unique()
if len(missing_stadiums) > 0:
    print(f"\nWarning: {len(missing_stadiums)} stadiums not found in mapping:")
    for stadium in missing_stadiums:
        print(f"  - {stadium}")
    
    # Fill missing values with NaN or a default
    combined_data['time_zone_offset'] = combined_data['time_zone_offset'].fillna(np.nan)
# Out:
# Created mapping for 60 stadiums

# %%
# Add team timezone column to your DataFrame
# Assuming you have a 'team' column in your DataFrame
combined_data['team_timezone_offset'] = combined_data['player_team'].map(team_timezones)
combined_data['team_timezone'] = combined_data['player_team'].map(team_timezones_abbr)

# Check for any teams not in the mapping
missing_teams = combined_data[combined_data['team_timezone_offset'].isna()]['player_team'].unique()
if len(missing_teams) > 0:
    print(f"Warning: {len(missing_teams)} teams not found in mapping:")
    for team in missing_teams:
        print(f"  - {team}")
    
    # Fill missing values
    combined_data['team_timezone_offset'] = combined_data['team_timezone_offset'].fillna(np.nan)
    combined_data['team_timezone'] = combined_data['team_timezone'].fillna('Unknown')

# Verify the mapping
print("\nTeam timezone distribution (numerical offset):")
print(combined_data['team_timezone_offset'].value_counts().sort_index())

print("\nTeam timezone distribution (abbreviation):")
print(combined_data['team_timezone'].value_counts())

# Show a sample
print("\nSample data with team timezone columns:")
sample_cols = ['player_team', 'team_timezone_offset', 'team_timezone']
print(combined_data[sample_cols].head(15))
# Out:
# Team timezone distribution (numerical offset):
# team_timezone_offset
# -8    18771
# -7     7196
# -6    26978
# -5    67494
# Name: count, dtype: int64
#
# Team timezone distribution (abbreviation):
# team_timezone
# ET    67494
# CT    26978
# PT    18771
# MT     7196
# Name: count, dtype: int64
#
# Sample data with team timezone columns:
#        player_team  team_timezone_offset team_timezone
# 0   Denver Broncos                    -7            MT
# 1   Denver Broncos                    -7            MT
# 2   Denver Broncos                    -7            MT
# 3   Denver Broncos                    -7            MT
# 4   Denver Broncos                    -7            MT
# 5   Denver Broncos                    -7            MT
# 6   Denver Broncos                    -7            MT
# 7   Denver Broncos                    -7            MT
# 8   Denver Broncos                    -7            MT
# 9   Denver Broncos                    -7            MT
# 10  Denver Broncos                    -7            MT
# 11  Denver Broncos                    -7            MT
# 12  Denver Broncos                    -7            MT
# 13  Denver Broncos                    -7            MT
# 14  Denver Broncos                    -7            MT

# %%
# Calculate the time zone difference (game location vs team's home)
combined_data['game_tz_difference'] = combined_data['time_zone_offset'] - combined_data['team_timezone_offset']

# Check the results
print("Time zone difference distribution:")
print(combined_data['game_tz_difference'].value_counts().sort_index())

print("\nDescriptive statistics for time zone difference:")
print(combined_data['game_tz_difference'].describe())

# Show a sample
print("\nSample data with time zone difference:")
sample_cols = ['stadium', 'player_team', 'time_zone_offset', 'team_timezone_offset', 'game_tz_difference']
print(combined_data[sample_cols].head(15))
# Out:
# Time zone difference distribution:
# game_tz_difference
# -3     3659
# -2     3713
# -1     9868
#  0    84592
#  1     9465
#  2     3694
#  3     4209
#  5      707
#  6      178
#  7       45
#  8      309
# Name: count, dtype: int64
#
# Descriptive statistics for time zone difference:
# count    120439.000000
# mean          0.071397
# std           1.171261
# min          -3.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           8.000000
# Name: game_tz_difference, dtype: float64
#
# Sample data with time zone difference:
#                                 stadium     player_team  time_zone_offset  \
# 0   Sports Authority Field at Mile High  Denver Broncos                -7
# 1   Sports Authority Field at Mile High  Denver Broncos                -7
# 2   Sports Authority Field at Mile High  Denver Broncos                -7
# 3   Sports Authority Field at Mile High  Denver Broncos                -7
# 4   Sports Authority Field at Mile High  Denver Broncos                -7
# 5   Sports Authority Field at Mile High  Denver Broncos                -7
# 6   Sports Authority Field at Mile High  Denver Broncos                -7
# 7   Sports Authority Field at Mile High  Denver Broncos                -7
# 8   Sports Authority Field at Mile High  Denver Broncos                -7
# 9   Sports Authority Field at Mile High  Denver Broncos                -7
# 10  Sports Authority Field at Mile High  Denver Broncos                -7
# 11  Sports Authority Field at Mile High  Denver Broncos                -7
# 12  Sports Authority Field at Mile High  Denver Broncos                -7
# 13  Sports Authority Field at Mile High  Denver Broncos                -7
# 14  Sports Authority Field at Mile High  Denver Broncos                -7
#
#     team_timezone_offset  game_tz_difference
# 0                     -7                   0
# 1                     -7                   0
# 2                     -7                   0
# 3                     -7                   0
# 4                     -7                   0
# 5                     -7                   0
# 6                     -7                   0
# 7                     -7                   0
# 8                     -7                   0
# 9                     -7                   0
# 10                    -7                   0
# 11                    -7                   0
# 12                    -7                   0
# 13                    -7                   0
# 14                    -7                   0

# %%
# Add travel direction and magnitude
def add_travel_features(df, tz_diff_col='game_tz_difference'):
    """
    Add comprehensive travel features based on timezone difference
    """
    df = df.copy()
    
    # 1. Basic travel direction
    df['travel_direction'] = np.select(
        [
            df[tz_diff_col] == 0,
            df[tz_diff_col] > 0,
            df[tz_diff_col] < 0
        ],
        ['home', 'east', 'west'],
        default='unknown'
    )
    
    # 2. Absolute timezone difference (magnitude)
    df['tz_diff_magnitude'] = df[tz_diff_col].abs()
    
    # 3. Travel category based on magnitude
    conditions = [
        df[tz_diff_col] == 0,
        df['tz_diff_magnitude'] == 1,
        df['tz_diff_magnitude'] == 2,
        df['tz_diff_magnitude'] == 3,
        df['tz_diff_magnitude'] >= 4
    ]
    
    categories = ['home', '1_hr', '2_hr', '3_hr', '4+_hr']
    df['travel_magnitude'] = np.select(conditions, categories, default='unknown')
    
    # 4. Is long travel? (3+ hours difference)
    df['is_long_travel'] = df['tz_diff_magnitude'] >= 3
    
    # 5. Detailed travel description
    def get_travel_description(row):
        tz_diff = row[tz_diff_col]
        if pd.isna(tz_diff):
            return 'unknown'
        if tz_diff == 0:
            return 'home_game'
        direction = 'east' if tz_diff > 0 else 'west'
        hours = abs(int(tz_diff))
        return f'travel_{direction}_{hours}_hours'
    
    df['travel_description'] = df.apply(get_travel_description, axis=1)
    
    return df

# Apply the function
combined_data = add_travel_features(combined_data, 'game_tz_difference')

# Analyze the results
print("Travel analysis:")
print("=" * 50)

# Direction breakdown
print("\n1. Travel Direction:")
print(combined_data['travel_direction'].value_counts().sort_index())

# Magnitude breakdown
print("\n2. Travel Magnitude:")
print(combined_data['travel_magnitude'].value_counts().sort_index())

# Long travel analysis
print("\n3. Long Travel Analysis:")
long_travel_pct = combined_data['is_long_travel'].mean() * 100
print(f"Games with long travel (3+ hours): {long_travel_pct:.1f}%")

# Most common travel scenarios
print("\n4. Most Common Travel Scenarios:")
common_scenarios = combined_data['travel_description'].value_counts().head(10)
for scenario, count in common_scenarios.items():
    pct = (count / len(combined_data)) * 100
    print(f"  {scenario}: {count} games ({pct:.1f}%)")

# Sample output
print("\n5. Sample Data:")
sample = combined_data[['player_team', 'game_tz_difference', 'travel_direction', 
                       'travel_magnitude', 'travel_description']].head(10)
print(sample)
# Out:
# Travel analysis:
# ==================================================
#
# 1. Travel Direction:
# travel_direction
# east    18607
# home    84592
# west    17240
# Name: count, dtype: int64
#
# 2. Travel Magnitude:
# travel_magnitude
# 1_hr     19333
# 2_hr      7407
# 3_hr      7868
# 4+_hr     1239
# home     84592
# Name: count, dtype: int64
#
# 3. Long Travel Analysis:
# Games with long travel (3+ hours): 7.6%
#
# 4. Most Common Travel Scenarios:
#   home_game: 84592 games (70.2%)
#   travel_west_1_hours: 9868 games (8.2%)
#   travel_east_1_hours: 9465 games (7.9%)
#   travel_east_3_hours: 4209 games (3.5%)
#   travel_west_2_hours: 3713 games (3.1%)
#   travel_east_2_hours: 3694 games (3.1%)
#   travel_west_3_hours: 3659 games (3.0%)
#   travel_east_5_hours: 707 games (0.6%)
#   travel_east_8_hours: 309 games (0.3%)
#   travel_east_6_hours: 178 games (0.1%)
#
# 5. Sample Data:
#       player_team  game_tz_difference travel_direction travel_magnitude  \
# 0  Denver Broncos                   0             home             home
# 1  Denver Broncos                   0             home             home
# 2  Denver Broncos                   0             home             home
# 3  Denver Broncos                   0             home             home
# 4  Denver Broncos                   0             home             home
# 5  Denver Broncos                   0             home             home
# 6  Denver Broncos                   0             home             home
# 7  Denver Broncos                   0             home             home
# 8  Denver Broncos                   0             home             home
# 9  Denver Broncos                   0             home             home
#
#   travel_description
# 0          home_game
# 1          home_game
# 2          home_game
# 3          home_game
# 4          home_game
# 5          home_game
# 6          home_game
# 7          home_game
# 8          home_game
# 9          home_game

# %%
# combined_data['travel_description'].unique()
combined_data.to_csv('player_snap_data_tz.csv')

# %%
player_snap_data_tz = pd.read_csv('player_snap_data_tz.csv')
# player_snap_data_tz
# Out:
# C:\Users\bchm5\AppData\Local\Temp\ipykernel_18924\868635974.py:1: DtypeWarning: Columns (14,82,84,90,122,138) have mixed types. Specify dtype option on import or set low_memory=False.
#   player_snap_data_tz = pd.read_csv('player_snap_data_tz.csv')
