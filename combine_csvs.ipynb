# %%
import pandas as pd

injury_data = pd.read_csv('player_injury_data.csv')
stats_data = pd.read_csv('player_snap_data_tz_miles_elevation.csv')
# Out:
# C:\Users\bchm5\AppData\Local\Temp\ipykernel_31076\476027904.py:4: DtypeWarning: Columns (8,14,82,84,90,122,138) have mixed types. Specify dtype option on import or set low_memory=False.
#   stats_data = pd.read_csv('player_snap_data_tz_miles_elevation.csv')

# %%
injury_data["date"] = (
    injury_data["date"]
    .astype(str)
    .str.replace(",", "", regex=False)
    .str.lower()
)

stats_data["date"] = (
    stats_data["date"]
    .astype(str)
    .str.replace(",", "", regex=False)
    .str.lower()
)

injury_data["player_team"] = injury_data["player_team"].str.split().str[-1]

stats_data["player_team"] = stats_data["player_team"].str.split().str[-1]

# %%
# Create a mapping dictionary
month_mapping = {
    'january': 'jan',
    'february': 'feb', 
    'march': 'mar',
    'april': 'apr',
    'may': 'may',
    'june': 'jun',
    'july': 'jul',
    'august': 'aug',
    'september': 'sep',
    'october': 'oct',
    'november': 'nov',
    'december': 'dec'
}

# Apply to your dataframe
injury_data['date'] = injury_data['date'].copy()

for full, abbr in month_mapping.items():
    injury_data['date'] = injury_data['date'].str.replace(full, abbr, case=False, regex=False)

# print(injury_data[['date']].head())

# %%
injury_data
# stats_data
# Out:
#               player_name                 date player_team position  \
# 0           Vernon Butler  thursday sep 8 2016    Panthers       DT
# 1              A.J. Klein  thursday sep 8 2016    Panthers       LB
# 2            Dean Marlowe  thursday sep 8 2016    Panthers        S
# 3             Kapri Bibbs  thursday sep 8 2016     Broncos       RB
# 4           James Ferentz  thursday sep 8 2016     Broncos        C
# ...                   ...                  ...         ...      ...
# 55443  Clark Phillips III   monday dec 29 2025     Falcons       CB
# 55444          Kyle Pitts   monday dec 29 2025     Falcons       TE
# 55445   Teagan Quitoriano   monday dec 29 2025     Falcons       TE
# 55446         Sam Roberts   monday dec 29 2025     Falcons       DT
# 55447     Charlie Woerner   monday dec 29 2025     Falcons       TE
#
#         injury_lcoation                    practice_status game_status\t\t
# 0                  Hand     Full Participation in Practice    Questionable
# 1                  Back     Full Participation in Practice    Questionable
# 2             Hamstring  Limited Participation in Practice        Doubtful
# 3                   NaN     Full Participation in Practice             NaN
# 4                  Knee  Limited Participation in Practice    Questionable
# ...                 ...                                ...             ...
# 55443  Triceps, Illness    Did Not Participate In Practice             Out
# 55444               NaN  Limited Participation in Practice             NaN
# 55445               NaN     Full Participation in Practice             NaN
# 55446       Knee, Ankle  Limited Participation in Practice             Out
# 55447               NaN    Did Not Participate In Practice             NaN
#
# [55448 rows x 7 columns]

# %%
inner_merged_data = pd.merge(
    injury_data, 
    stats_data, 
    on=['player_name', 'date', 'player_team'],
    how='inner' 
)

# inner_merged_data

outer_merged_data = pd.merge(
    injury_data, 
    stats_data, 
    on=['player_name', 'date', 'player_team'],
    how='outer' 
)

# outer_merged_data

left_merged_data = pd.merge(
    injury_data, 
    stats_data, 
    on=['player_name', 'date', 'player_team'],
    how='left' 
)

left_merged_data
# Out:
#               player_name                 date player_team position  \
# 0           Vernon Butler  thursday sep 8 2016    Panthers       DT
# 1              A.J. Klein  thursday sep 8 2016    Panthers       LB
# 2            Dean Marlowe  thursday sep 8 2016    Panthers        S
# 3             Kapri Bibbs  thursday sep 8 2016     Broncos       RB
# 4           James Ferentz  thursday sep 8 2016     Broncos        C
# ...                   ...                  ...         ...      ...
# 55450  Clark Phillips III   monday dec 29 2025     Falcons       CB
# 55451          Kyle Pitts   monday dec 29 2025     Falcons       TE
# 55452   Teagan Quitoriano   monday dec 29 2025     Falcons       TE
# 55453         Sam Roberts   monday dec 29 2025     Falcons       DT
# 55454     Charlie Woerner   monday dec 29 2025     Falcons       TE
#
#         injury_lcoation                    practice_status game_status\t\t  \
# 0                  Hand     Full Participation in Practice    Questionable
# 1                  Back     Full Participation in Practice    Questionable
# 2             Hamstring  Limited Participation in Practice        Doubtful
# 3                   NaN     Full Participation in Practice             NaN
# 4                  Knee  Limited Participation in Practice    Questionable
# ...                 ...                                ...             ...
# 55450  Triceps, Illness    Did Not Participate In Practice             Out
# 55451               NaN  Limited Participation in Practice             NaN
# 55452               NaN     Full Participation in Practice             NaN
# 55453       Knee, Ankle  Limited Participation in Practice             Out
# 55454               NaN    Did Not Participate In Practice             NaN
#
#           index       game_id  snap_count  ... travel_direction  \
# 0          84.0  201609080den        24.0  ...             west
# 1           0.0  201609080den        19.0  ...             west
# 2           NaN           NaN         NaN  ...              NaN
# 3          50.0  201609080den        17.0  ...             home
# 4           NaN           NaN         NaN  ...              NaN
# ...         ...           ...         ...  ...              ...
# 55450       NaN           NaN         NaN  ...              NaN
# 55451  281363.0  202512290atl        49.0  ...             home
# 55452  281386.0  202512290atl        33.0  ...             home
# 55453       NaN           NaN         NaN  ...              NaN
# 55454  281315.0  202512290atl        60.0  ...             home
#
#       tz_diff_magnitude travel_magnitude is_long_travel   travel_description  \
# 0                   2.0             2_hr          False  travel_west_2_hours
# 1                   2.0             2_hr          False  travel_west_2_hours
# 2                   NaN              NaN            NaN                  NaN
# 3                   0.0             home          False            home_game
# 4                   NaN              NaN            NaN                  NaN
# ...                 ...              ...            ...                  ...
# 55450               NaN              NaN            NaN                  NaN
# 55451               0.0             home          False            home_game
# 55452               0.0             home          False            home_game
# 55453               NaN              NaN            NaN                  NaN
# 55454               0.0             home          False            home_game
#
#       game_stadium_elevation           team_home_stadium team_home_elevation  \
# 0                     1609.3     Bank of America Stadium               229.2
# 1                     1609.3     Bank of America Stadium               229.2
# 2                        NaN                         NaN                 NaN
# 3                     1609.3  Empower Field at Mile High              1609.3
# 4                        NaN                         NaN                 NaN
# ...                      ...                         ...                 ...
# 55450                    NaN                         NaN                 NaN
# 55451                  314.9       Mercedes-Benz Stadium               314.9
# 55452                  314.9       Mercedes-Benz Stadium               314.9
# 55453                    NaN                         NaN                 NaN
# 55454                  314.9       Mercedes-Benz Stadium               314.9
#
#       elevation_difference_m elevation_difference_abs_m
# 0                     1380.1                     1380.1
# 1                     1380.1                     1380.1
# 2                        NaN                        NaN
# 3                        0.0                        0.0
# 4                        NaN                        NaN
# ...                      ...                        ...
# 55450                    NaN                        NaN
# 55451                    0.0                        0.0
# 55452                    0.0                        0.0
# 55453                    NaN                        NaN
# 55454                    0.0                        0.0
#
# [55455 rows x 158 columns]

# %%
# merged_data.to_csv('merged_data.csv')

# %%
print(len(left_merged_data['player_team'].unique()))
left_merged_data
# Out:
# 34
#               player_name                 date player_team position  \
# 0           Vernon Butler  thursday sep 8 2016    Panthers       DT
# 1              A.J. Klein  thursday sep 8 2016    Panthers       LB
# 2            Dean Marlowe  thursday sep 8 2016    Panthers        S
# 3             Kapri Bibbs  thursday sep 8 2016     Broncos       RB
# 4           James Ferentz  thursday sep 8 2016     Broncos        C
# ...                   ...                  ...         ...      ...
# 55450  Clark Phillips III   monday dec 29 2025     Falcons       CB
# 55451          Kyle Pitts   monday dec 29 2025     Falcons       TE
# 55452   Teagan Quitoriano   monday dec 29 2025     Falcons       TE
# 55453         Sam Roberts   monday dec 29 2025     Falcons       DT
# 55454     Charlie Woerner   monday dec 29 2025     Falcons       TE
#
#         injury_lcoation                    practice_status game_status\t\t  \
# 0                  Hand     Full Participation in Practice    Questionable
# 1                  Back     Full Participation in Practice    Questionable
# 2             Hamstring  Limited Participation in Practice        Doubtful
# 3                   NaN     Full Participation in Practice             NaN
# 4                  Knee  Limited Participation in Practice    Questionable
# ...                 ...                                ...             ...
# 55450  Triceps, Illness    Did Not Participate In Practice             Out
# 55451               NaN  Limited Participation in Practice             NaN
# 55452               NaN     Full Participation in Practice             NaN
# 55453       Knee, Ankle  Limited Participation in Practice             Out
# 55454               NaN    Did Not Participate In Practice             NaN
#
#           index       game_id  snap_count  ... travel_direction  \
# 0          84.0  201609080den        24.0  ...             west
# 1           0.0  201609080den        19.0  ...             west
# 2           NaN           NaN         NaN  ...              NaN
# 3          50.0  201609080den        17.0  ...             home
# 4           NaN           NaN         NaN  ...              NaN
# ...         ...           ...         ...  ...              ...
# 55450       NaN           NaN         NaN  ...              NaN
# 55451  281363.0  202512290atl        49.0  ...             home
# 55452  281386.0  202512290atl        33.0  ...             home
# 55453       NaN           NaN         NaN  ...              NaN
# 55454  281315.0  202512290atl        60.0  ...             home
#
#       tz_diff_magnitude travel_magnitude is_long_travel   travel_description  \
# 0                   2.0             2_hr          False  travel_west_2_hours
# 1                   2.0             2_hr          False  travel_west_2_hours
# 2                   NaN              NaN            NaN                  NaN
# 3                   0.0             home          False            home_game
# 4                   NaN              NaN            NaN                  NaN
# ...                 ...              ...            ...                  ...
# 55450               NaN              NaN            NaN                  NaN
# 55451               0.0             home          False            home_game
# 55452               0.0             home          False            home_game
# 55453               NaN              NaN            NaN                  NaN
# 55454               0.0             home          False            home_game
#
#       game_stadium_elevation           team_home_stadium team_home_elevation  \
# 0                     1609.3     Bank of America Stadium               229.2
# 1                     1609.3     Bank of America Stadium               229.2
# 2                        NaN                         NaN                 NaN
# 3                     1609.3  Empower Field at Mile High              1609.3
# 4                        NaN                         NaN                 NaN
# ...                      ...                         ...                 ...
# 55450                    NaN                         NaN                 NaN
# 55451                  314.9       Mercedes-Benz Stadium               314.9
# 55452                  314.9       Mercedes-Benz Stadium               314.9
# 55453                    NaN                         NaN                 NaN
# 55454                  314.9       Mercedes-Benz Stadium               314.9
#
#       elevation_difference_m elevation_difference_abs_m
# 0                     1380.1                     1380.1
# 1                     1380.1                     1380.1
# 2                        NaN                        NaN
# 3                        0.0                        0.0
# 4                        NaN                        NaN
# ...                      ...                        ...
# 55450                    NaN                        NaN
# 55451                    0.0                        0.0
# 55452                    0.0                        0.0
# 55453                    NaN                        NaN
# 55454                    0.0                        0.0
#
# [55455 rows x 158 columns]

# %%
left_merged_data.to_csv('data/left_merged_data.csv')
outer_merged_data.to_csv('data/outer_merged_data.csv')
inner_merged_data.to_csv('data/inner_merged_data.csv')
